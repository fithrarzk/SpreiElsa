# %% [markdown]
# ## 0. Setup

# %% [markdown]
# # RNN/LSTM Image Captioning Notebook
#
# Notebook utama RNN/LSTM untuk Kaggle dan lokal. Semua kebutuhan Kaggle yang dulu ada di launcher sekarang ada di notebook ini: discovery dataset Flickr8k, fallback split, mode demo/full, output directory, training RNN/LSTM, evaluasi Keras vs scratch, analisis, dan bonus.

# %%
import csv
import json
import os
import random
import shutil
import sys
import time
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


def find_repo_root() -> Path:
    current = Path.cwd().resolve()
    if (current / "src" / "notebook").exists():
        return current
    for parent in current.parents:
        if (parent / "src" / "notebook").exists():
            return parent

    input_root = Path("/kaggle/input")
    code_slug = os.getenv("CODE_DATASET_SLUG", "").strip()
    search_roots = []
    if code_slug and (input_root / code_slug).exists():
        search_roots.append(input_root / code_slug)
    if input_root.exists():
        search_roots.append(input_root)

    for root in search_roots:
        candidates = [root, *root.glob("**/*")]
        for candidate in candidates:
            if candidate.is_dir() and (candidate / "src" / "notebook").exists():
                working_copy = Path("/kaggle/working/SpreiElsa")
                if Path("/kaggle/working").exists():
                    if working_copy.exists():
                        shutil.rmtree(working_copy)
                    shutil.copytree(candidate, working_copy)
                    return working_copy
                return candidate

    raise FileNotFoundError(
        "Repo root tidak ditemukan. Jalankan notebook dari root repo atau upload repo sebagai Kaggle Dataset "
        "dan, jika perlu, isi environment CODE_DATASET_SLUG."
    )


REPO_ROOT = find_repo_root()
os.chdir(REPO_ROOT)

RNN_SRC = REPO_ROOT / "src" / "rnn-lstm"
UTILS_SRC = REPO_ROOT / "src" / "utils"
for path in (str(REPO_ROOT), str(RNN_SRC), str(UTILS_SRC)):
    if path not in sys.path:
        sys.path.insert(0, path)

print("Repo root:", REPO_ROOT)
print("TensorFlow:", tf.__version__)
# Out:
# 2026-05-16 06:47:09.464749: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778914029.860279      57 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778914029.972876      57 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778914030.958368      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778914030.958412      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778914030.958415      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778914030.958418      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Repo root: /kaggle/working/SpreiElsa
# TensorFlow: 2.19.0

# %%
from feature_extraction import extract_flickr8k_features, load_features
from text_utils import (
    clean_caption,
    decode_caption,
    encode_caption,
    load_flickr8k_captions,
    load_vocab,
)
import preprocess_flickr8k
from decoder_model import build_dataset, build_decoder_model, masked_accuracy, masked_loss
from train_decoder import DecoderExperimentConfig, train_one
from caption_model import CaptionModel
from evaluate_captioning import evaluate
from metrics import bleu_score, meteor_score, tokenize
from rnn import SimpleRNNCell, SimpleRNNDecoder
from lstm import LSTMCell, LSTMDecoder

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

IS_KAGGLE = Path("/kaggle/input").exists()


def env_flag(name: str, default: bool) -> bool:
    raw = os.getenv(name)
    if raw is None:
        return default
    return raw.strip().lower() in {"1", "true", "yes", "y", "on"}


RUN_MODE = os.getenv("RUN_MODE", "full" if IS_KAGGLE else "local").strip().lower()
if RUN_MODE == "smoke":
    RUN_MODE = "demo"
if RUN_MODE not in {"local", "demo", "full"}:
    raise ValueError("RUN_MODE harus 'local', 'demo', atau 'full'")

DEMO_MODE = RUN_MODE == "demo"
DEMO_SYNTHETIC_FEATURES = env_flag("DEMO_SYNTHETIC_FEATURES", DEMO_MODE)

RUN_EXTRACT_FEATURES = env_flag("RUN_EXTRACT_FEATURES", IS_KAGGLE and not DEMO_SYNTHETIC_FEATURES)
RUN_PREPROCESS = env_flag("RUN_PREPROCESS", IS_KAGGLE or DEMO_MODE)
RUN_TRAIN_RNN = env_flag("RUN_TRAIN_RNN", IS_KAGGLE or DEMO_MODE)
RUN_TRAIN_LSTM = env_flag("RUN_TRAIN_LSTM", IS_KAGGLE or DEMO_MODE)
RUN_TRAIN_INIT_INJECT = env_flag("RUN_TRAIN_INIT_INJECT", IS_KAGGLE and RUN_MODE == "full")
RUN_FULL_EVAL = env_flag("RUN_FULL_EVAL", IS_KAGGLE or DEMO_MODE)

N_EVAL = int(os.getenv("N_EVAL", "5" if DEMO_MODE else "50"))
N_BATCH = int(os.getenv("N_BATCH", str(N_EVAL)))
BATCH_SIZE = int(os.getenv("BATCH_SIZE", "8" if DEMO_MODE else "64"))
EPOCHS = int(os.getenv("EPOCHS", "1" if DEMO_MODE else "50"))
MAX_SEQ_LEN = int(os.getenv("MAX_SEQ_LEN", "20" if DEMO_MODE else "35"))
EMBED_DIM = int(os.getenv("EMBED_DIM", "64" if DEMO_MODE else "256"))
FEATURE_DIM = int(os.getenv("FEATURE_DIM", "2048"))
LEARNING_RATE = float(os.getenv("LEARNING_RATE", "1e-3"))

DEMO_FLICKR_TRAIN_IMAGES = int(os.getenv("DEMO_FLICKR_TRAIN_IMAGES", "18"))
DEMO_FLICKR_VAL_IMAGES = int(os.getenv("DEMO_FLICKR_VAL_IMAGES", "4"))
DEMO_FLICKR_TEST_IMAGES = int(os.getenv("DEMO_FLICKR_TEST_IMAGES", "4"))

FULL_VARIATIONS = [
    {"n_layers": 1, "hidden_size": 128},
    {"n_layers": 1, "hidden_size": 256},
    {"n_layers": 2, "hidden_size": 128},
    {"n_layers": 2, "hidden_size": 256},
    {"n_layers": 3, "hidden_size": 128},
    {"n_layers": 3, "hidden_size": 256},
]
DEMO_VARIATIONS = [{"n_layers": 1, "hidden_size": 64}]
VARIATIONS = DEMO_VARIATIONS if DEMO_MODE else FULL_VARIATIONS

{
    "RUN_MODE": RUN_MODE,
    "IS_KAGGLE": IS_KAGGLE,
    "DEMO_SYNTHETIC_FEATURES": DEMO_SYNTHETIC_FEATURES,
    "RUN_EXTRACT_FEATURES": RUN_EXTRACT_FEATURES,
    "RUN_PREPROCESS": RUN_PREPROCESS,
    "RUN_TRAIN_RNN": RUN_TRAIN_RNN,
    "RUN_TRAIN_LSTM": RUN_TRAIN_LSTM,
    "RUN_FULL_EVAL": RUN_FULL_EVAL,
    "EPOCHS": EPOCHS,
    "VARIATIONS": VARIATIONS,
}
# Out:
# {'RUN_MODE': 'full',
#  'IS_KAGGLE': True,
#  'DEMO_SYNTHETIC_FEATURES': False,
#  'RUN_EXTRACT_FEATURES': True,
#  'RUN_PREPROCESS': True,
#  'RUN_TRAIN_RNN': True,
#  'RUN_TRAIN_LSTM': True,
#  'RUN_FULL_EVAL': True,
#  'EPOCHS': 50,
#  'VARIATIONS': [{'n_layers': 1, 'hidden_size': 128},
#   {'n_layers': 1, 'hidden_size': 256},
#   {'n_layers': 2, 'hidden_size': 128},
#   {'n_layers': 2, 'hidden_size': 256},
#   {'n_layers': 3, 'hidden_size': 128},
#   {'n_layers': 3, 'hidden_size': 256}]}

# %% [markdown]
# ## 0a. Path Resolution

# %%
FLICKR8K_DATASET_SLUG = os.getenv("FLICKR8K_DATASET_SLUG", "").strip()
INPUT_ROOT = Path("/kaggle/input")
WORK_ROOT = Path("/kaggle/working") if IS_KAGGLE else REPO_ROOT / "outputs"
DEFAULT_WORKING_DIR = (
    WORK_ROOT / "outputs_demo" / "rnn_lstm" if IS_KAGGLE and DEMO_MODE else
    WORK_ROOT / "outputs" / "rnn_lstm" if IS_KAGGLE else
    WORK_ROOT / ("rnn_lstm_demo" if DEMO_MODE else "rnn_lstm")
)
WORKING_DIR = Path(os.getenv("WORKING_DIR", DEFAULT_WORKING_DIR))
FEATURES_PATH = WORKING_DIR / "features.npy"
PREP_DIR = WORKING_DIR / "preprocessed"
VOCAB_PATH = PREP_DIR / "vocab.json"
SPLITS_JSON = PREP_DIR / "splits.json"
MODELS_DIR = WORKING_DIR / "models"
EVAL_DIR = WORKING_DIR / "eval"
PLOTS_DIR = WORKING_DIR / "plots"

for p in (WORKING_DIR, PREP_DIR, MODELS_DIR, EVAL_DIR, PLOTS_DIR):
    p.mkdir(parents=True, exist_ok=True)

IMAGE_EXTS = {".jpg", ".jpeg", ".png", ".bmp", ".webp"}


def optional_path(value):
    if value in (None, ""):
        return None
    return Path(value)


def path_from_slug(slug: str):
    if not IS_KAGGLE or not slug:
        return None
    path = INPUT_ROOT / slug
    return path if path.exists() else None


def find_file(name_options, preferred_slug=""):
    roots = []
    explicit = path_from_slug(preferred_slug)
    if explicit:
        roots.append(explicit)
    if IS_KAGGLE and INPUT_ROOT.exists():
        roots.append(INPUT_ROOT)
    for root in roots:
        for name in name_options:
            matches = sorted(root.glob(f"**/{name}"))
            if matches:
                return matches[0]
    return None


def find_dir(name_options, preferred_slug=""):
    roots = []
    explicit = path_from_slug(preferred_slug)
    if explicit:
        roots.append(explicit)
    if IS_KAGGLE and INPUT_ROOT.exists():
        roots.append(INPUT_ROOT)
    for root in roots:
        for name in name_options:
            matches = sorted(path for path in root.glob(f"**/{name}") if path.is_dir())
            if matches:
                return matches[0]
    return None


def caption_image_names(path: Path):
    names = []
    if not path or not path.exists():
        return names
    with path.open("r", encoding="utf-8") as handle:
        for line in handle:
            line = line.strip()
            if not line or line.lower().startswith("image,caption"):
                continue
            left = line.split("\t", 1)[0] if "\t" in line else line.split(",", 1)[0]
            name = left.split("#", 1)[0].strip()
            if name:
                names.append(name)
    return sorted(set(names))


def write_split(path: Path, names):
    path.parent.mkdir(parents=True, exist_ok=True)
    path.write_text("\n".join(names) + "\n", encoding="utf-8")


def image_map(image_dir: Path):
    if image_dir is None or not image_dir.exists():
        return {}
    return {p.name: p for p in image_dir.iterdir() if p.is_file() and p.suffix.lower() in IMAGE_EXTS}


def discover_flickr8k_paths():
    env_root = optional_path(os.getenv("FLICKR8K_ROOT"))
    env_images = optional_path(os.getenv("FLICKR8K_IMAGES"))
    env_captions = optional_path(os.getenv("FLICKR8K_CAPTIONS"))
    env_train = optional_path(os.getenv("FLICKR8K_TRAIN_SPLIT"))
    env_val = optional_path(os.getenv("FLICKR8K_VAL_SPLIT"))
    env_test = optional_path(os.getenv("FLICKR8K_TEST_SPLIT"))

    if IS_KAGGLE:
        root = env_root or path_from_slug(FLICKR8K_DATASET_SLUG) or find_dir(["flickr8k", "Flickr8k"], FLICKR8K_DATASET_SLUG)
        images = env_images or find_dir(["Images", "Flicker8k_Dataset", "Flickr8k_Dataset"], FLICKR8K_DATASET_SLUG)
        captions = env_captions or find_file(["captions.txt", "Flickr8k.token.txt"], FLICKR8K_DATASET_SLUG)
        train = env_train or find_file(["Flickr_8k.trainImages.txt", "Flickr8k.trainImages.txt"], FLICKR8K_DATASET_SLUG)
        val = env_val or find_file(["Flickr_8k.devImages.txt", "Flickr8k.devImages.txt"], FLICKR8K_DATASET_SLUG)
        test = env_test or find_file(["Flickr_8k.testImages.txt", "Flickr8k.testImages.txt"], FLICKR8K_DATASET_SLUG)
    else:
        root = env_root or REPO_ROOT / "data" / "flickr8k"
        images = env_images or root / "Images"
        captions = env_captions or root / "captions.txt"
        train = env_train or root / "Flickr_8k.trainImages.txt"
        val = env_val or root / "Flickr_8k.devImages.txt"
        test = env_test or root / "Flickr_8k.testImages.txt"
    return root, images, captions, train, val, test


FLICKR_INPUT, IMAGE_DIR, CAPTIONS_PATH, TRAIN_SPLIT, VAL_SPLIT, TEST_SPLIT = discover_flickr8k_paths()


def create_synthetic_demo_dataset():
    rng = np.random.default_rng(SEED)
    demo_dir = WORKING_DIR / "synthetic_flickr8k"
    image_dir = demo_dir / "Images"
    image_dir.mkdir(parents=True, exist_ok=True)
    total = DEMO_FLICKR_TRAIN_IMAGES + DEMO_FLICKR_VAL_IMAGES + DEMO_FLICKR_TEST_IMAGES
    names = [f"demo_{i:03d}.jpg" for i in range(total)]

    try:
        from PIL import Image
        for i, name in enumerate(names):
            arr = np.zeros((64, 64, 3), dtype=np.uint8)
            arr[..., 0] = (37 * i) % 255
            arr[..., 1] = (83 * i) % 255
            arr[..., 2] = (127 * i) % 255
            Image.fromarray(arr).save(image_dir / name)
    except Exception as exc:
        print("Synthetic image write skipped:", exc)

    templates = [
        "a person stands near a small dog",
        "a child plays outside on the grass",
        "two people walk beside the water",
        "a group sits near a bright street",
        "a dog runs through a green field",
    ]
    captions_path = demo_dir / "captions.txt"
    with captions_path.open("w", encoding="utf-8") as handle:
        handle.write("image,caption\n")
        for i, name in enumerate(names):
            handle.write(f"{name},{templates[i % len(templates)]}\n")
            handle.write(f"{name},{templates[(i + 1) % len(templates)]}\n")

    split_dir = demo_dir / "splits"
    train_names = names[:DEMO_FLICKR_TRAIN_IMAGES]
    val_names = names[DEMO_FLICKR_TRAIN_IMAGES:DEMO_FLICKR_TRAIN_IMAGES + DEMO_FLICKR_VAL_IMAGES]
    test_names = names[DEMO_FLICKR_TRAIN_IMAGES + DEMO_FLICKR_VAL_IMAGES:]
    train_path = split_dir / "Flickr_8k.trainImages.txt"
    val_path = split_dir / "Flickr_8k.devImages.txt"
    test_path = split_dir / "Flickr_8k.testImages.txt"
    write_split(train_path, train_names)
    write_split(val_path, val_names)
    write_split(test_path, test_names)

    features = {name: rng.normal(0.0, 0.25, size=(FEATURE_DIM,)).astype(np.float32) for name in names}
    np.save(FEATURES_PATH, features)
    print("Synthetic demo dataset:", demo_dir)
    print("Synthetic cached features:", FEATURES_PATH)
    return demo_dir, image_dir, captions_path, train_path, val_path, test_path


def make_real_demo_subset(image_dir: Path, captions_path: Path):
    lookup = image_map(image_dir)
    caption_names = [name for name in caption_image_names(captions_path) if name in lookup]
    if not caption_names:
        caption_names = sorted(lookup)
    need = DEMO_FLICKR_TRAIN_IMAGES + DEMO_FLICKR_VAL_IMAGES + DEMO_FLICKR_TEST_IMAGES
    selected = caption_names[:need]
    if len(selected) < 3:
        raise RuntimeError("Demo Flickr8k gagal: gambar/caption yang cocok terlalu sedikit.")

    demo_images = WORKING_DIR / "demo_images"
    if demo_images.exists():
        shutil.rmtree(demo_images)
    demo_images.mkdir(parents=True, exist_ok=True)
    for name in selected:
        shutil.copy2(lookup[name], demo_images / name)

    split_dir = WORKING_DIR / "demo_splits"
    train_names = selected[:DEMO_FLICKR_TRAIN_IMAGES]
    val_names = selected[DEMO_FLICKR_TRAIN_IMAGES:DEMO_FLICKR_TRAIN_IMAGES + DEMO_FLICKR_VAL_IMAGES]
    test_names = selected[DEMO_FLICKR_TRAIN_IMAGES + DEMO_FLICKR_VAL_IMAGES:]
    if not val_names:
        val_names = train_names[-1:]
    if not test_names:
        test_names = val_names[-1:]
    train_path = split_dir / "Flickr_8k.trainImages.txt"
    val_path = split_dir / "Flickr_8k.devImages.txt"
    test_path = split_dir / "Flickr_8k.testImages.txt"
    write_split(train_path, train_names)
    write_split(val_path, val_names)
    write_split(test_path, test_names)
    print("Real demo Flickr images:", len(selected), demo_images)
    return demo_images, train_path, val_path, test_path


if DEMO_MODE and DEMO_SYNTHETIC_FEATURES:
    FLICKR_INPUT, IMAGE_DIR, CAPTIONS_PATH, TRAIN_SPLIT, VAL_SPLIT, TEST_SPLIT = create_synthetic_demo_dataset()
    RUN_EXTRACT_FEATURES = False
elif DEMO_MODE and IMAGE_DIR is not None and CAPTIONS_PATH is not None and IMAGE_DIR.exists() and CAPTIONS_PATH.exists():
    IMAGE_DIR, TRAIN_SPLIT, VAL_SPLIT, TEST_SPLIT = make_real_demo_subset(IMAGE_DIR, CAPTIONS_PATH)

if CAPTIONS_PATH is not None and CAPTIONS_PATH.exists() and not all(
    p is not None and p.exists() for p in (TRAIN_SPLIT, VAL_SPLIT, TEST_SPLIT)
):
    split_dir = WORKING_DIR / "generated_splits"
    names = caption_image_names(CAPTIONS_PATH)
    if not names and IMAGE_DIR is not None:
        names = sorted(image_map(IMAGE_DIR))
    if len(names) < 3:
        raise RuntimeError("Tidak bisa generate split Flickr8k: nama gambar terlalu sedikit atau captions tidak terbaca.")
    train_names = names[: min(6000, max(1, int(0.75 * len(names))))]
    val_start = len(train_names)
    val_end = min(val_start + 1000, val_start + max(1, int(0.125 * len(names))))
    val_names = names[val_start:val_end]
    test_names = names[val_end:]
    if not test_names:
        test_names = val_names[-max(1, len(val_names) // 2):]
        val_names = val_names[:-len(test_names)] or test_names
    TRAIN_SPLIT = split_dir / "Flickr_8k.trainImages.txt"
    VAL_SPLIT = split_dir / "Flickr_8k.devImages.txt"
    TEST_SPLIT = split_dir / "Flickr_8k.testImages.txt"
    write_split(TRAIN_SPLIT, train_names)
    write_split(VAL_SPLIT, val_names)
    write_split(TEST_SPLIT, test_names)
    print("Generated Flickr8k splits:", len(train_names), len(val_names), len(test_names))

for key, value in {
    "FLICKR8K_ROOT": FLICKR_INPUT,
    "FLICKR8K_IMAGES": IMAGE_DIR,
    "FLICKR8K_CAPTIONS": CAPTIONS_PATH,
    "FLICKR8K_TRAIN_SPLIT": TRAIN_SPLIT,
    "FLICKR8K_VAL_SPLIT": VAL_SPLIT,
    "FLICKR8K_TEST_SPLIT": TEST_SPLIT,
    "WORKING_DIR": WORKING_DIR,
}.items():
    if value is not None:
        os.environ[key] = str(value)

{
    "RUN_MODE": RUN_MODE,
    "IMAGE_DIR": str(IMAGE_DIR),
    "CAPTIONS_PATH": str(CAPTIONS_PATH),
    "TRAIN_SPLIT": str(TRAIN_SPLIT),
    "VAL_SPLIT": str(VAL_SPLIT),
    "TEST_SPLIT": str(TEST_SPLIT),
    "FEATURES_PATH": str(FEATURES_PATH),
    "VOCAB_PATH": str(VOCAB_PATH),
    "MODELS_DIR": str(MODELS_DIR),
}
# Out:
# {'RUN_MODE': 'full',
#  'IMAGE_DIR': '/kaggle/input/datasets/adityajn105/flickr8k/Images',
#  'CAPTIONS_PATH': '/kaggle/input/datasets/adityajn105/flickr8k/captions.txt',
#  'TRAIN_SPLIT': '/kaggle/input/datasets/indahtangdililing1/elsasprei/SpreiElsa/src/outputs/rnn_lstm/generated_splits/Flickr_8k.trainImages.txt',
#  'VAL_SPLIT': '/kaggle/input/datasets/indahtangdililing1/elsasprei/SpreiElsa/src/outputs/rnn_lstm/generated_splits/Flickr_8k.devImages.txt',
#  'TEST_SPLIT': '/kaggle/input/datasets/indahtangdililing1/elsasprei/SpreiElsa/src/outputs/rnn_lstm/generated_splits/Flickr_8k.testImages.txt',
#  'FEATURES_PATH': '/kaggle/working/outputs/rnn_lstm/features.npy',
#  'VOCAB_PATH': '/kaggle/working/outputs/rnn_lstm/preprocessed/vocab.json',
#  'MODELS_DIR': '/kaggle/working/outputs/rnn_lstm/models'}

# %%
def read_json(path: Path, default=None):
    if not path.exists():
        return default
    with path.open("r", encoding="utf-8") as handle:
        return json.load(handle)


def write_json(path: Path, data):
    path.parent.mkdir(parents=True, exist_ok=True)
    with path.open("w", encoding="utf-8") as handle:
        json.dump(data, handle, indent=2)


def load_splits(path: Path):
    data = read_json(path, {"train": [], "val": [], "test": []})
    return {"train": data.get("train", []), "val": data.get("val", []), "test": data.get("test", [])}


def has_required_files():
    required = [CAPTIONS_PATH, VOCAB_PATH, SPLITS_JSON, FEATURES_PATH]
    missing = [str(p) for p in required if not p.exists()]
    if missing:
        print("File belum tersedia:")
        for p in missing:
            print(" -", p)
        return False
    return True

# %% [markdown]
# ## 1. CNN Encoder Frozen

# %%
if RUN_EXTRACT_FEATURES:
    if not IMAGE_DIR.exists():
        raise FileNotFoundError(IMAGE_DIR)
    features = extract_flickr8k_features(
        images_dir=str(IMAGE_DIR),
        output_path=str(FEATURES_PATH),
        encoder_name="inceptionv3",
        batch_size=32,
    )
    print("Extracted features:", len(features))
elif FEATURES_PATH.exists():
    features_preview = load_features(str(FEATURES_PATH))
    print("Loaded cached features:", len(features_preview))
else:
    print("Feature cache belum ada. Set RUN_EXTRACT_FEATURES=True di Kaggle untuk membuat features.npy.")
# Out:
# I0000 00:00:1778914175.431236      57 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1778914175.434045      57 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778914182.256353     128 service.cc:152] XLA service 0x7a0858255b90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778914182.256391     128 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1778914182.256395     128 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1778914183.590279     128 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1778914193.142284     128 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#   [8091/8091]
# Extracted features: 8091

# %%
def get_image_feature(img_path: Path):
    from tensorflow.keras.applications import InceptionV3
    from tensorflow.keras.applications.inception_v3 import preprocess_input
    from tensorflow.keras.preprocessing.image import img_to_array, load_img

    encoder = InceptionV3(weights="imagenet", include_top=False, pooling="avg")
    image = load_img(img_path, target_size=(299, 299))
    arr = img_to_array(image)[np.newaxis]
    return encoder.predict(preprocess_input(arr), verbose=0)[0].astype(np.float32)

# %% [markdown]
# ## 2. Caption Preprocessing

# %%
if RUN_PREPROCESS:
    summary = preprocess_flickr8k.preprocess(
        captions_file=CAPTIONS_PATH,
        train_split=TRAIN_SPLIT,
        val_split=VAL_SPLIT,
        test_split=TEST_SPLIT,
        output_dir=PREP_DIR,
        min_freq=1,
    )
    summary
else:
    summary = read_json(PREP_DIR / "summary.json", {})
    summary

# %%
if CAPTIONS_PATH.exists():
    captions = load_flickr8k_captions(str(CAPTIONS_PATH))
    print("Total image captions:", len(captions))
    first_key = next(iter(captions), None)
    if first_key:
        print(first_key, "->", captions[first_key][:2])
else:
    captions = {}
    print("captions.txt belum ditemukan.")
# Out:
# Total image captions: 8091
# 1000268201_693b08cb0e.jpg -> ['A child in a pink dress is climbing up a set of stairs in an entry way .', 'A girl going into a wooden building .']

# %%
if VOCAB_PATH.exists():
    word2idx, idx2word = load_vocab(VOCAB_PATH)
    vocab_size = len(word2idx)
    START_IDX = word2idx["<start>"]
    END_IDX = word2idx["<end>"]
    PAD_IDX = word2idx["<pad>"]
    print("Vocab size:", vocab_size)
    print("Special tokens:", {"pad": PAD_IDX, "start": START_IDX, "end": END_IDX})
else:
    word2idx, idx2word, vocab_size = {}, {}, 0
    print("vocab.json belum ada.")
# Out:
# Vocab size: 7684
# Special tokens: {'pad': 0, 'start': 1, 'end': 2}

# %%
if captions and word2idx:
    lengths = [len(encode_caption(cap, word2idx, max_len=None)) for caps in captions.values() for cap in caps]
    print("Caption length min/mean/p95/max:", int(np.min(lengths)), float(np.mean(lengths)), int(np.percentile(lengths, 95)), int(np.max(lengths)))
    plt.figure(figsize=(6, 3))
    plt.hist(lengths, bins=30)
    plt.xlabel("caption length incl. special tokens")
    plt.ylabel("count")
    plt.tight_layout()
    plt.show()
# Out:
# Caption length min/mean/p95/max: 3 12.785761957730813 20 37

# %% [markdown]
# ## 3. Dataset Builder Smoke Test

# %%
if has_required_files():
    splits = load_splits(SPLITS_JSON)
    features = load_features(str(FEATURES_PATH))
    train_names = [name for name in splits["train"] if name in captions and name in features][:8]
    ds_preview = build_dataset(
        train_names,
        captions,
        features,
        word2idx,
        max_seq_len=MAX_SEQ_LEN,
        batch_size=4,
        shuffle=False,
        injection_method="pre",
    )
    for (img_batch, tok_batch), y_batch in ds_preview.take(1):
        print("image_features", img_batch.shape)
        print("caption_tokens", tok_batch.shape)
        print("target", y_batch.shape)
else:
    splits, features = {"train": [], "val": [], "test": []}, {}
# Out:
# image_features (4, 2048)
# caption_tokens (4, 34)
# target (4, 35)

# %% [markdown]
# ## 4. RNN Decoder Training

# %%
def make_config(decoder_type, n_layers, hidden_size, injection_method="pre"):
    return DecoderExperimentConfig(
        decoder_type=decoder_type,
        n_layers=n_layers,
        hidden_size=hidden_size,
        embed_dim=EMBED_DIM,
        max_seq_len=MAX_SEQ_LEN,
        feature_dim=FEATURE_DIM,
        learning_rate=LEARNING_RATE,
        injection_method=injection_method,
    )


def decoder_configs(decoder_type, injection_method="pre"):
    return [make_config(decoder_type, **variation, injection_method=injection_method) for variation in VARIATIONS]

rnn_configs = decoder_configs("rnn")
[c.experiment_id for c in rnn_configs]
# Out:
# ['rnn_pre_l1_h128_e256_m35',
#  'rnn_pre_l1_h256_e256_m35',
#  'rnn_pre_l2_h128_e256_m35',
#  'rnn_pre_l2_h256_e256_m35',
#  'rnn_pre_l3_h128_e256_m35',
#  'rnn_pre_l3_h256_e256_m35']

# %%
def train_grid(configs, run_flag):
    trained, skipped = [], []
    if not run_flag:
        print("Training flag False; hanya cek artefak yang sudah ada.")
    if not has_required_files():
        return trained, skipped

    splits = load_splits(SPLITS_JSON)
    features = load_features(str(FEATURES_PATH))
    for config in configs:
        exp_dir = MODELS_DIR / config.experiment_id
        if (exp_dir / "model.keras").exists():
            skipped.append(config.experiment_id)
            continue
        if run_flag:
            print("Training", config.experiment_id)
            train_one(config, captions, splits, features, word2idx, MODELS_DIR, BATCH_SIZE, EPOCHS, SEED)
            trained.append(config.experiment_id)
        else:
            skipped.append(config.experiment_id)
    return trained, skipped

# %%
rnn_trained, rnn_skipped = train_grid(rnn_configs, RUN_TRAIN_RNN)
{"trained": rnn_trained, "available_or_skipped": rnn_skipped}
# Out:
# Training rnn_pre_l1_h128_e256_m35
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 25ms/step - loss: 5.7123 - masked_accuracy: 0.1577 - val_loss: 4.6941 - val_masked_accuracy: 0.2310 - learning_rate: 0.0010
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 4.4907 - masked_accuracy: 0.2368 - val_loss: 4.4952 - val_masked_accuracy: 0.2401 - learning_rate: 0.0010
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 4.2861 - masked_accuracy: 0.2464 - val_loss: 4.3685 - val_masked_accuracy: 0.2521 - learning_rate: 0.0010
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 4.1183 - masked_accuracy: 0.2641 - val_loss: 4.2935 - val_masked_accuracy: 0.2576 - learning_rate: 0.0010
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 4.0125 - masked_accuracy: 0.2685 - val_loss: 4.2475 - val_masked_accuracy: 0.2608 - learning_rate: 0.0010
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - loss: 3.9297 - masked_accuracy: 0.2732 - val_loss: 4.2254 - val_masked_accuracy: 0.2620 - learning_rate: 0.0010
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - loss: 3.8742 - masked_accuracy: 0.2763 - val_loss: 4.2026 - val_masked_accuracy: 0.2633 - learning_rate: 0.0010
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - loss: 3.8269 - masked_accuracy: 0.2787 - val_loss: 4.1848 - val_masked_accuracy: 0.2644 - learning_rate: 0.0010
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.7768 - masked_accuracy: 0.2815 - val_loss: 4.1585 - val_masked_accuracy: 0.2673 - learning_rate: 0.0010
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.7386 - masked_accuracy: 0.2841 - val_loss: 4.1486 - val_masked_accuracy: 0.2689 - learning_rate: 0.0010
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.6961 - masked_accuracy: 0.2875 - val_loss: 4.1456 - val_masked_accuracy: 0.2684 - learning_rate: 0.0010
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.6621 - masked_accuracy: 0.2883 - val_loss: 4.1355 - val_masked_accuracy: 0.2693 - learning_rate: 0.0010
# Epoch 13/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.6298 - masked_accuracy: 0.2917 - val_loss: 4.1311 - val_masked_accuracy: 0.2689 - learning_rate: 0.0010
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.6017 - masked_accuracy: 0.2914 - val_loss: 4.1196 - val_masked_accuracy: 0.2706 - learning_rate: 0.0010
# Epoch 15/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.5724 - masked_accuracy: 0.2942 - val_loss: 4.1202 - val_masked_accuracy: 0.2709 - learning_rate: 0.0010
# Epoch 16/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.5538 - masked_accuracy: 0.2953 - val_loss: 4.1233 - val_masked_accuracy: 0.2702 - learning_rate: 0.0010
# Epoch 17/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.5335 - masked_accuracy: 0.2970 - val_loss: 4.1163 - val_masked_accuracy: 0.2689 - learning_rate: 0.0010
# Epoch 18/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.5069 - masked_accuracy: 0.2986 - val_loss: 4.1163 - val_masked_accuracy: 0.2678 - learning_rate: 0.0010
# Epoch 19/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.4907 - masked_accuracy: 0.3006 - val_loss: 4.1218 - val_masked_accuracy: 0.2715 - learning_rate: 0.0010
# Epoch 20/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.4732 - masked_accuracy: 0.3007
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.4732 - masked_accuracy: 0.3007 - val_loss: 4.1282 - val_masked_accuracy: 0.2693 - learning_rate: 0.0010
# Epoch 21/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.4336 - masked_accuracy: 0.3037 - val_loss: 4.1104 - val_masked_accuracy: 0.2712 - learning_rate: 5.0000e-04
# Epoch 22/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.4123 - masked_accuracy: 0.3053 - val_loss: 4.1059 - val_masked_accuracy: 0.2703 - learning_rate: 5.0000e-04
# Epoch 23/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.4033 - masked_accuracy: 0.3057 - val_loss: 4.1051 - val_masked_accuracy: 0.2722 - learning_rate: 5.0000e-04
# Epoch 24/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.3870 - masked_accuracy: 0.3068 - val_loss: 4.1054 - val_masked_accuracy: 0.2723 - learning_rate: 5.0000e-04
# Epoch 25/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.3738 - masked_accuracy: 0.3086 - val_loss: 4.1068 - val_masked_accuracy: 0.2702 - learning_rate: 5.0000e-04
# Epoch 26/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.3708 - masked_accuracy: 0.3090
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.3708 - masked_accuracy: 0.3090 - val_loss: 4.1102 - val_masked_accuracy: 0.2725 - learning_rate: 5.0000e-04
# Epoch 27/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.3541 - masked_accuracy: 0.3100 - val_loss: 4.1036 - val_masked_accuracy: 0.2721 - learning_rate: 2.5000e-04
# Epoch 28/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.3396 - masked_accuracy: 0.3112 - val_loss: 4.1046 - val_masked_accuracy: 0.2729 - learning_rate: 2.5000e-04
# Epoch 29/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.3321 - masked_accuracy: 0.3115 - val_loss: 4.1037 - val_masked_accuracy: 0.2720 - learning_rate: 2.5000e-04
# Epoch 30/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.3272 - masked_accuracy: 0.3133
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.3272 - masked_accuracy: 0.3133 - val_loss: 4.1060 - val_masked_accuracy: 0.2719 - learning_rate: 2.5000e-04
# Epoch 31/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.3229 - masked_accuracy: 0.3125 - val_loss: 4.1021 - val_masked_accuracy: 0.2723 - learning_rate: 1.2500e-04
# Epoch 32/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.3195 - masked_accuracy: 0.3136 - val_loss: 4.1020 - val_masked_accuracy: 0.2726 - learning_rate: 1.2500e-04
# Epoch 33/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.3096 - masked_accuracy: 0.3136 - val_loss: 4.1036 - val_masked_accuracy: 0.2723 - learning_rate: 1.2500e-04
# Epoch 34/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.3081 - masked_accuracy: 0.3144 - val_loss: 4.1031 - val_masked_accuracy: 0.2730 - learning_rate: 1.2500e-04
# Epoch 35/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.3092 - masked_accuracy: 0.3136
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.3092 - masked_accuracy: 0.3136 - val_loss: 4.1035 - val_masked_accuracy: 0.2730 - learning_rate: 1.2500e-04
# Epoch 36/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.2958 - masked_accuracy: 0.3151 - val_loss: 4.1034 - val_masked_accuracy: 0.2724 - learning_rate: 6.2500e-05
# Epoch 37/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 3.3001 - masked_accuracy: 0.3155 - val_loss: 4.1032 - val_masked_accuracy: 0.2725 - learning_rate: 6.2500e-05
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 32.
# Training rnn_pre_l1_h256_e256_m35
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - loss: 5.4154 - masked_accuracy: 0.1749 - val_loss: 4.5993 - val_masked_accuracy: 0.2353 - learning_rate: 0.0010
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 4.3738 - masked_accuracy: 0.2448 - val_loss: 4.3425 - val_masked_accuracy: 0.2541 - learning_rate: 0.0010
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 4.0871 - masked_accuracy: 0.2634 - val_loss: 4.2100 - val_masked_accuracy: 0.2614 - learning_rate: 0.0010
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.9202 - masked_accuracy: 0.2729 - val_loss: 4.1667 - val_masked_accuracy: 0.2646 - learning_rate: 0.0010
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.8068 - masked_accuracy: 0.2801 - val_loss: 4.1247 - val_masked_accuracy: 0.2662 - learning_rate: 0.0010
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.7131 - masked_accuracy: 0.2861 - val_loss: 4.1046 - val_masked_accuracy: 0.2700 - learning_rate: 0.0010
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.6415 - masked_accuracy: 0.2897 - val_loss: 4.0899 - val_masked_accuracy: 0.2708 - learning_rate: 0.0010
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.5977 - masked_accuracy: 0.2928 - val_loss: 4.0936 - val_masked_accuracy: 0.2697 - learning_rate: 0.0010
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.5444 - masked_accuracy: 0.2949 - val_loss: 4.0797 - val_masked_accuracy: 0.2733 - learning_rate: 0.0010
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.4985 - masked_accuracy: 0.2977 - val_loss: 4.0770 - val_masked_accuracy: 0.2739 - learning_rate: 0.0010
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.4487 - masked_accuracy: 0.3019 - val_loss: 4.0827 - val_masked_accuracy: 0.2751 - learning_rate: 0.0010
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.4132 - masked_accuracy: 0.3039 - val_loss: 4.0778 - val_masked_accuracy: 0.2729 - learning_rate: 0.0010
# Epoch 13/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.3714 - masked_accuracy: 0.3075
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.3714 - masked_accuracy: 0.3075 - val_loss: 4.0797 - val_masked_accuracy: 0.2747 - learning_rate: 0.0010
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.3039 - masked_accuracy: 0.3127 - val_loss: 4.0499 - val_masked_accuracy: 0.2780 - learning_rate: 5.0000e-04
# Epoch 15/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.2661 - masked_accuracy: 0.3155 - val_loss: 4.0480 - val_masked_accuracy: 0.2785 - learning_rate: 5.0000e-04
# Epoch 16/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.2522 - masked_accuracy: 0.3165 - val_loss: 4.0492 - val_masked_accuracy: 0.2776 - learning_rate: 5.0000e-04
# Epoch 17/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.2321 - masked_accuracy: 0.3187 - val_loss: 4.0487 - val_masked_accuracy: 0.2780 - learning_rate: 5.0000e-04
# Epoch 18/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.2176 - masked_accuracy: 0.3213
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.2176 - masked_accuracy: 0.3213 - val_loss: 4.0545 - val_masked_accuracy: 0.2763 - learning_rate: 5.0000e-04
# Epoch 19/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.1859 - masked_accuracy: 0.3243 - val_loss: 4.0438 - val_masked_accuracy: 0.2790 - learning_rate: 2.5000e-04
# Epoch 20/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.1640 - masked_accuracy: 0.3259 - val_loss: 4.0428 - val_masked_accuracy: 0.2778 - learning_rate: 2.5000e-04
# Epoch 21/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.1570 - masked_accuracy: 0.3258 - val_loss: 4.0449 - val_masked_accuracy: 0.2789 - learning_rate: 2.5000e-04
# Epoch 22/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.1466 - masked_accuracy: 0.3267 - val_loss: 4.0446 - val_masked_accuracy: 0.2790 - learning_rate: 2.5000e-04
# Epoch 23/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.1391 - masked_accuracy: 0.3275
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.1391 - masked_accuracy: 0.3275 - val_loss: 4.0442 - val_masked_accuracy: 0.2807 - learning_rate: 2.5000e-04
# Epoch 24/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.1194 - masked_accuracy: 0.3307 - val_loss: 4.0423 - val_masked_accuracy: 0.2802 - learning_rate: 1.2500e-04
# Epoch 25/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.1101 - masked_accuracy: 0.3320 - val_loss: 4.0418 - val_masked_accuracy: 0.2803 - learning_rate: 1.2500e-04
# Epoch 26/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.1054 - masked_accuracy: 0.3320 - val_loss: 4.0438 - val_masked_accuracy: 0.2801 - learning_rate: 1.2500e-04
# Epoch 27/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.1049 - masked_accuracy: 0.3320 - val_loss: 4.0415 - val_masked_accuracy: 0.2799 - learning_rate: 1.2500e-04
# Epoch 28/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.0941 - masked_accuracy: 0.3334 - val_loss: 4.0438 - val_masked_accuracy: 0.2806 - learning_rate: 1.2500e-04
# Epoch 29/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.0920 - masked_accuracy: 0.3326 - val_loss: 4.0430 - val_masked_accuracy: 0.2810 - learning_rate: 1.2500e-04
# Epoch 30/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.0883 - masked_accuracy: 0.3338
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.0883 - masked_accuracy: 0.3338 - val_loss: 4.0467 - val_masked_accuracy: 0.2807 - learning_rate: 1.2500e-04
# Epoch 31/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.0830 - masked_accuracy: 0.3329 - val_loss: 4.0443 - val_masked_accuracy: 0.2816 - learning_rate: 6.2500e-05
# Epoch 32/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.0793 - masked_accuracy: 0.3336 - val_loss: 4.0444 - val_masked_accuracy: 0.2815 - learning_rate: 6.2500e-05
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 27.
# Training rnn_pre_l2_h128_e256_m35
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 5.7526 - masked_accuracy: 0.1495 - val_loss: 4.7089 - val_masked_accuracy: 0.2295 - learning_rate: 0.0010
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 4.5213 - masked_accuracy: 0.2341 - val_loss: 4.5126 - val_masked_accuracy: 0.2421 - learning_rate: 0.0010
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 4.3001 - masked_accuracy: 0.2510 - val_loss: 4.3957 - val_masked_accuracy: 0.2499 - learning_rate: 0.0010
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 4.1646 - masked_accuracy: 0.2595 - val_loss: 4.3311 - val_masked_accuracy: 0.2548 - learning_rate: 0.0010
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 4.0785 - masked_accuracy: 0.2641 - val_loss: 4.2849 - val_masked_accuracy: 0.2584 - learning_rate: 0.0010
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 4.0013 - masked_accuracy: 0.2678 - val_loss: 4.2569 - val_masked_accuracy: 0.2598 - learning_rate: 0.0010
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 3.9416 - masked_accuracy: 0.2717 - val_loss: 4.2324 - val_masked_accuracy: 0.2597 - learning_rate: 0.0010
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.9034 - masked_accuracy: 0.2728 - val_loss: 4.2042 - val_masked_accuracy: 0.2616 - learning_rate: 0.0010
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.8610 - masked_accuracy: 0.2745 - val_loss: 4.1899 - val_masked_accuracy: 0.2628 - learning_rate: 0.0010
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.8208 - masked_accuracy: 0.2772 - val_loss: 4.1712 - val_masked_accuracy: 0.2656 - learning_rate: 0.0010
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.7841 - masked_accuracy: 0.2787 - val_loss: 4.1747 - val_masked_accuracy: 0.2642 - learning_rate: 0.0010
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.7648 - masked_accuracy: 0.2793 - val_loss: 4.1487 - val_masked_accuracy: 0.2646 - learning_rate: 0.0010
# Epoch 13/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 3.7267 - masked_accuracy: 0.2825 - val_loss: 4.1462 - val_masked_accuracy: 0.2653 - learning_rate: 0.0010
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 3.7007 - masked_accuracy: 0.2825 - val_loss: 4.1333 - val_masked_accuracy: 0.2673 - learning_rate: 0.0010
# Epoch 15/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.6833 - masked_accuracy: 0.2834 - val_loss: 4.1336 - val_masked_accuracy: 0.2660 - learning_rate: 0.0010
# Epoch 16/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.6694 - masked_accuracy: 0.2850 - val_loss: 4.1277 - val_masked_accuracy: 0.2670 - learning_rate: 0.0010
# Epoch 17/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 3.6554 - masked_accuracy: 0.2849 - val_loss: 4.1241 - val_masked_accuracy: 0.2661 - learning_rate: 0.0010
# Epoch 18/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.6336 - masked_accuracy: 0.2864 - val_loss: 4.1282 - val_masked_accuracy: 0.2658 - learning_rate: 0.0010
# Epoch 19/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.6194 - masked_accuracy: 0.2878 - val_loss: 4.1223 - val_masked_accuracy: 0.2690 - learning_rate: 0.0010
# Epoch 20/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.6037 - masked_accuracy: 0.2886 - val_loss: 4.1256 - val_masked_accuracy: 0.2665 - learning_rate: 0.0010
# Epoch 21/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.5889 - masked_accuracy: 0.2878 - val_loss: 4.1271 - val_masked_accuracy: 0.2679 - learning_rate: 0.0010
# Epoch 22/50
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.5836 - masked_accuracy: 0.2881
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.5837 - masked_accuracy: 0.2881 - val_loss: 4.1280 - val_masked_accuracy: 0.2685 - learning_rate: 0.0010
# Epoch 23/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.5556 - masked_accuracy: 0.2896 - val_loss: 4.1033 - val_masked_accuracy: 0.2700 - learning_rate: 5.0000e-04
# Epoch 24/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 3.5231 - masked_accuracy: 0.2931 - val_loss: 4.1039 - val_masked_accuracy: 0.2707 - learning_rate: 5.0000e-04
# Epoch 25/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.5166 - masked_accuracy: 0.2933 - val_loss: 4.1008 - val_masked_accuracy: 0.2690 - learning_rate: 5.0000e-04
# Epoch 26/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.5123 - masked_accuracy: 0.2930 - val_loss: 4.1020 - val_masked_accuracy: 0.2697 - learning_rate: 5.0000e-04
# Epoch 27/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.5057 - masked_accuracy: 0.2934 - val_loss: 4.0983 - val_masked_accuracy: 0.2699 - learning_rate: 5.0000e-04
# Epoch 28/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 3.4929 - masked_accuracy: 0.2953 - val_loss: 4.1070 - val_masked_accuracy: 0.2706 - learning_rate: 5.0000e-04
# Epoch 29/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 3.4863 - masked_accuracy: 0.2944 - val_loss: 4.0984 - val_masked_accuracy: 0.2716 - learning_rate: 5.0000e-04
# Epoch 30/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.4826 - masked_accuracy: 0.2949
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.4826 - masked_accuracy: 0.2949 - val_loss: 4.1007 - val_masked_accuracy: 0.2711 - learning_rate: 5.0000e-04
# Epoch 31/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 3.4680 - masked_accuracy: 0.2961 - val_loss: 4.0952 - val_masked_accuracy: 0.2707 - learning_rate: 2.5000e-04
# Epoch 32/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.4575 - masked_accuracy: 0.2962 - val_loss: 4.0951 - val_masked_accuracy: 0.2707 - learning_rate: 2.5000e-04
# Epoch 33/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.4525 - masked_accuracy: 0.2961 - val_loss: 4.0963 - val_masked_accuracy: 0.2690 - learning_rate: 2.5000e-04
# Epoch 34/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.4436 - masked_accuracy: 0.2979 - val_loss: 4.1001 - val_masked_accuracy: 0.2700 - learning_rate: 2.5000e-04
# Epoch 35/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.4454 - masked_accuracy: 0.2967
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.4454 - masked_accuracy: 0.2967 - val_loss: 4.0978 - val_masked_accuracy: 0.2701 - learning_rate: 2.5000e-04
# Epoch 36/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.4310 - masked_accuracy: 0.2996 - val_loss: 4.0938 - val_masked_accuracy: 0.2711 - learning_rate: 1.2500e-04
# Epoch 37/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.4313 - masked_accuracy: 0.2999 - val_loss: 4.0925 - val_masked_accuracy: 0.2717 - learning_rate: 1.2500e-04
# Epoch 38/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.4247 - masked_accuracy: 0.2987 - val_loss: 4.0898 - val_masked_accuracy: 0.2720 - learning_rate: 1.2500e-04
# Epoch 39/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.4253 - masked_accuracy: 0.2994 - val_loss: 4.0889 - val_masked_accuracy: 0.2719 - learning_rate: 1.2500e-04
# Epoch 40/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.4240 - masked_accuracy: 0.2991 - val_loss: 4.0934 - val_masked_accuracy: 0.2717 - learning_rate: 1.2500e-04
# Epoch 41/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.4240 - masked_accuracy: 0.2991 - val_loss: 4.0919 - val_masked_accuracy: 0.2722 - learning_rate: 1.2500e-04
# Epoch 42/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.4171 - masked_accuracy: 0.2996
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 3.4171 - masked_accuracy: 0.2996 - val_loss: 4.0914 - val_masked_accuracy: 0.2716 - learning_rate: 1.2500e-04
# Epoch 43/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.4190 - masked_accuracy: 0.3005 - val_loss: 4.0916 - val_masked_accuracy: 0.2717 - learning_rate: 6.2500e-05
# Epoch 44/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 3.4147 - masked_accuracy: 0.3005 - val_loss: 4.0916 - val_masked_accuracy: 0.2717 - learning_rate: 6.2500e-05
# Epoch 44: early stopping
# Restoring model weights from the end of the best epoch: 39.
# Training rnn_pre_l2_h256_e256_m35
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 36ms/step - loss: 5.4541 - masked_accuracy: 0.1728 - val_loss: 4.6206 - val_masked_accuracy: 0.2347 - learning_rate: 0.0010
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 4.4192 - masked_accuracy: 0.2396 - val_loss: 4.4177 - val_masked_accuracy: 0.2501 - learning_rate: 0.0010
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - loss: 4.1754 - masked_accuracy: 0.2586 - val_loss: 4.3035 - val_masked_accuracy: 0.2578 - learning_rate: 0.0010
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - loss: 4.0317 - masked_accuracy: 0.2659 - val_loss: 4.2399 - val_masked_accuracy: 0.2602 - learning_rate: 0.0010
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.9270 - masked_accuracy: 0.2718 - val_loss: 4.1919 - val_masked_accuracy: 0.2639 - learning_rate: 0.0010
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.8343 - masked_accuracy: 0.2768 - val_loss: 4.1610 - val_masked_accuracy: 0.2684 - learning_rate: 0.0010
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.7615 - masked_accuracy: 0.2806 - val_loss: 4.1458 - val_masked_accuracy: 0.2651 - learning_rate: 0.0010
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.7213 - masked_accuracy: 0.2818 - val_loss: 4.1282 - val_masked_accuracy: 0.2668 - learning_rate: 0.0010
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.6731 - masked_accuracy: 0.2835 - val_loss: 4.1209 - val_masked_accuracy: 0.2687 - learning_rate: 0.0010
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.6353 - masked_accuracy: 0.2863 - val_loss: 4.1180 - val_masked_accuracy: 0.2708 - learning_rate: 0.0010
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.5984 - masked_accuracy: 0.2877 - val_loss: 4.1124 - val_masked_accuracy: 0.2685 - learning_rate: 0.0010
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.5675 - masked_accuracy: 0.2891 - val_loss: 4.1085 - val_masked_accuracy: 0.2679 - learning_rate: 0.0010
# Epoch 13/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.5341 - masked_accuracy: 0.2915 - val_loss: 4.1072 - val_masked_accuracy: 0.2710 - learning_rate: 0.0010
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.5093 - masked_accuracy: 0.2930 - val_loss: 4.0991 - val_masked_accuracy: 0.2723 - learning_rate: 0.0010
# Epoch 15/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.4856 - masked_accuracy: 0.2938 - val_loss: 4.1097 - val_masked_accuracy: 0.2702 - learning_rate: 0.0010
# Epoch 16/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.4663 - masked_accuracy: 0.2942 - val_loss: 4.1053 - val_masked_accuracy: 0.2715 - learning_rate: 0.0010
# Epoch 17/50
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.4524 - masked_accuracy: 0.2949
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.4525 - masked_accuracy: 0.2949 - val_loss: 4.1030 - val_masked_accuracy: 0.2703 - learning_rate: 0.0010
# Epoch 18/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.3878 - masked_accuracy: 0.3006 - val_loss: 4.0720 - val_masked_accuracy: 0.2735 - learning_rate: 5.0000e-04
# Epoch 19/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.3503 - masked_accuracy: 0.3046 - val_loss: 4.0724 - val_masked_accuracy: 0.2744 - learning_rate: 5.0000e-04
# Epoch 20/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.3378 - masked_accuracy: 0.3044 - val_loss: 4.0726 - val_masked_accuracy: 0.2744 - learning_rate: 5.0000e-04
# Epoch 21/50
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.3230 - masked_accuracy: 0.3052
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.3231 - masked_accuracy: 0.3052 - val_loss: 4.0720 - val_masked_accuracy: 0.2723 - learning_rate: 5.0000e-04
# Epoch 22/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.2944 - masked_accuracy: 0.3079 - val_loss: 4.0595 - val_masked_accuracy: 0.2755 - learning_rate: 2.5000e-04
# Epoch 23/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.2763 - masked_accuracy: 0.3090 - val_loss: 4.0583 - val_masked_accuracy: 0.2755 - learning_rate: 2.5000e-04
# Epoch 24/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.2648 - masked_accuracy: 0.3101 - val_loss: 4.0627 - val_masked_accuracy: 0.2755 - learning_rate: 2.5000e-04
# Epoch 25/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.2565 - masked_accuracy: 0.3116 - val_loss: 4.0632 - val_masked_accuracy: 0.2743 - learning_rate: 2.5000e-04
# Epoch 26/50
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.2548 - masked_accuracy: 0.3107
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.2548 - masked_accuracy: 0.3107 - val_loss: 4.0654 - val_masked_accuracy: 0.2744 - learning_rate: 2.5000e-04
# Epoch 27/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.2406 - masked_accuracy: 0.3112 - val_loss: 4.0579 - val_masked_accuracy: 0.2754 - learning_rate: 1.2500e-04
# Epoch 28/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.2268 - masked_accuracy: 0.3137 - val_loss: 4.0586 - val_masked_accuracy: 0.2763 - learning_rate: 1.2500e-04
# Epoch 29/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.2195 - masked_accuracy: 0.3131 - val_loss: 4.0582 - val_masked_accuracy: 0.2774 - learning_rate: 1.2500e-04
# Epoch 30/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.2211 - masked_accuracy: 0.3141
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.2211 - masked_accuracy: 0.3141 - val_loss: 4.0580 - val_masked_accuracy: 0.2757 - learning_rate: 1.2500e-04
# Epoch 31/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.2144 - masked_accuracy: 0.3148 - val_loss: 4.0581 - val_masked_accuracy: 0.2752 - learning_rate: 6.2500e-05
# Epoch 32/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.2100 - masked_accuracy: 0.3145 - val_loss: 4.0574 - val_masked_accuracy: 0.2757 - learning_rate: 6.2500e-05
# Epoch 33/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.2053 - masked_accuracy: 0.3156 - val_loss: 4.0574 - val_masked_accuracy: 0.2753 - learning_rate: 6.2500e-05
# Epoch 34/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.2043 - masked_accuracy: 0.3154 - val_loss: 4.0562 - val_masked_accuracy: 0.2757 - learning_rate: 6.2500e-05
# Epoch 35/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.2084 - masked_accuracy: 0.3135 - val_loss: 4.0559 - val_masked_accuracy: 0.2760 - learning_rate: 6.2500e-05
# Epoch 36/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.1958 - masked_accuracy: 0.3169 - val_loss: 4.0567 - val_masked_accuracy: 0.2762 - learning_rate: 6.2500e-05
# Epoch 37/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.1983 - masked_accuracy: 0.3158 - val_loss: 4.0571 - val_masked_accuracy: 0.2768 - learning_rate: 6.2500e-05
# Epoch 38/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.1968 - masked_accuracy: 0.3150
# Epoch 38: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.1968 - masked_accuracy: 0.3150 - val_loss: 4.0572 - val_masked_accuracy: 0.2754 - learning_rate: 6.2500e-05
# Epoch 39/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.1962 - masked_accuracy: 0.3160 - val_loss: 4.0572 - val_masked_accuracy: 0.2762 - learning_rate: 3.1250e-05
# Epoch 40/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3.1949 - masked_accuracy: 0.3162 - val_loss: 4.0573 - val_masked_accuracy: 0.2758 - learning_rate: 3.1250e-05
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 35.
# Training rnn_pre_l3_h128_e256_m35
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 26s 36ms/step - loss: 5.8409 - masked_accuracy: 0.1284 - val_loss: 4.9841 - val_masked_accuracy: 0.2181 - learning_rate: 0.0010
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 4.7317 - masked_accuracy: 0.2241 - val_loss: 4.6264 - val_masked_accuracy: 0.2326 - learning_rate: 0.0010
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 4.4431 - masked_accuracy: 0.2366 - val_loss: 4.5177 - val_masked_accuracy: 0.2377 - learning_rate: 0.0010
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 4.3136 - masked_accuracy: 0.2433 - val_loss: 4.4570 - val_masked_accuracy: 0.2418 - learning_rate: 0.0010
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 4.2359 - masked_accuracy: 0.2482 - val_loss: 4.4146 - val_masked_accuracy: 0.2455 - learning_rate: 0.0010
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 4.1684 - masked_accuracy: 0.2518 - val_loss: 4.3827 - val_masked_accuracy: 0.2489 - learning_rate: 0.0010
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 4.1169 - masked_accuracy: 0.2553 - val_loss: 4.3659 - val_masked_accuracy: 0.2510 - learning_rate: 0.0010
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 4.0891 - masked_accuracy: 0.2560 - val_loss: 4.3538 - val_masked_accuracy: 0.2499 - learning_rate: 0.0010
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 4.0483 - masked_accuracy: 0.2578 - val_loss: 4.3398 - val_masked_accuracy: 0.2509 - learning_rate: 0.0010
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 4.0246 - masked_accuracy: 0.2585 - val_loss: 4.3329 - val_masked_accuracy: 0.2513 - learning_rate: 0.0010
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 3.
e-04
# Epoch 31/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.3737 - masked_accuracy: 0.2973 - val_loss: 4.1214 - val_masked_accuracy: 0.2709 - learning_rate: 2.5000e-04
# Epoch 32/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.3752 - masked_accuracy: 0.2980
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.3752 - masked_accuracy: 0.2980 - val_loss: 4.1180 - val_masked_accuracy: 0.2702 - learning_rate: 2.5000e-04
# Epoch 33/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.3558 - masked_accuracy: 0.3003 - val_loss: 4.1152 - val_masked_accuracy: 0.2701 - learning_rate: 1.2500e-04
# Epoch 34/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.3480 - masked_accuracy: 0.2988 - val_loss: 4.1115 - val_masked_accuracy: 0.2720 - learning_rate: 1.2500e-04
# Epoch 35/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.3483 - masked_accuracy: 0.2993 - val_loss: 4.1137 - val_masked_accuracy: 0.2717 - learning_rate: 1.2500e-04
# Epoch 36/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.3356 - masked_accuracy: 0.3014 - val_loss: 4.1129 - val_masked_accuracy: 0.2705 - learning_rate: 1.2500e-04
# Epoch 37/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.3383 - masked_accuracy: 0.3007
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.3383 - masked_accuracy: 0.3007 - val_loss: 4.1132 - val_masked_accuracy: 0.2709 - learning_rate: 1.2500e-04
# Epoch 38/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.3269 - masked_accuracy: 0.3012 - val_loss: 4.1114 - val_masked_accuracy: 0.2708 - learning_rate: 6.2500e-05
# Epoch 39/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.3275 - masked_accuracy: 0.3010 - val_loss: 4.1120 - val_masked_accuracy: 0.2701 - learning_rate: 6.2500e-05
# Epoch 40/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.3269 - masked_accuracy: 0.3015 - val_loss: 4.1122 - val_masked_accuracy: 0.2707 - learning_rate: 6.2500e-05
# Epoch 41/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.3285 - masked_accuracy: 0.3007
# Epoch 41: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.3284 - masked_accuracy: 0.3007 - val_loss: 4.1133 - val_masked_accuracy: 0.2710 - learning_rate: 6.2500e-05
# Epoch 42/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.3206 - masked_accuracy: 0.3024 - val_loss: 4.1116 - val_masked_accuracy: 0.2711 - learning_rate: 3.1250e-05
# Epoch 43/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.3214 - masked_accuracy: 0.3016 - val_loss: 4.1118 - val_masked_accuracy: 0.2706 - learning_rate: 3.1250e-05
# Epoch 43: early stopping
# Restoring model weights from the end of the best epoch: 38.
# {'trained': ['rnn_pre_l1_h128_e256_m35',
#   'rnn_pre_l1_h256_e256_m35',
#   'rnn_pre_l2_h128_e256_m35',
#   'rnn_pre_l2_h256_e256_m35',
#   'rnn_pre_l3_h128_e256_m35',
#   'rnn_pre_l3_h256_e256_m35'],
#  'available_or_skipped': []}

# %%
def history_summary(experiment_id):
    exp_dir = MODELS_DIR / experiment_id
    history = read_json(exp_dir / "history.json", {})
    metrics = read_json(exp_dir / "metrics.json", {})
    config = read_json(exp_dir / "config.json", {})
    if not history and not metrics:
        return None
    return {
        "experiment": experiment_id,
        "decoder_type": config.get("decoder_type"),
        "injection": config.get("injection_method"),
        "layers": config.get("n_layers"),
        "hidden": config.get("hidden_size"),
        "loss": (history.get("loss") or [None])[-1],
        "val_loss": (history.get("val_loss") or [None])[-1],
        "param_count": metrics.get("param_count"),
    }


def summarize_decoder(decoder_type, injection="pre"):
    rows = []
    for config in decoder_configs(decoder_type, injection):
        row = history_summary(config.experiment_id)
        if row:
            rows.append(row)
    rows.sort(key=lambda r: float("inf") if r["val_loss"] is None else r["val_loss"])
    return rows

rnn_summary = summarize_decoder("rnn")
rnn_summary
# Out:
# [{'experiment': 'rnn_pre_l1_h256_e256_m35',
#   'decoder_type': 'rnn',
#   'injection': 'pre',
#   'layers': 1,
#   'hidden': 256,
#   'loss': 3.072021245956421,
#   'val_loss': 4.0443806648254395,
#   'param_count': 4597764},
#  {'experiment': 'rnn_pre_l2_h256_e256_m35',
#   'decoder_type': 'rnn',
#   'injection': 'pre',
#   'layers': 2,
#   'hidden': 256,
#   'loss': 3.1899187564849854,
#   'val_loss': 4.057292938232422,
#   'param_count': 4729092},
#  {'experiment': 'rnn_pre_l2_h128_e256_m35',
#   'decoder_type': 'rnn',
#   'injection': 'pre',
#   'layers': 2,
#   'hidden': 128,
#   'loss': 3.4139907360076904,
#   'val_loss': 4.0915656089782715,
#   'param_count': 3565060},
#  {'experiment': 'rnn_pre_l1_h128_e256_m35',
#   'decoder_type': 'rnn',
#   'injection': 'pre',
#   'layers': 1,
#   'hidden': 128,
#   'loss': 3.2973203659057617,
#   'val_loss': 4.103175163269043,
#   'param_count': 3532164},
#  {'experiment': 'rnn_pre_l3_h256_e256_m35',
#   'decoder_type': 'rnn',
#   'injection': 'pre',
#   'layers': 3,
#   'hidden': 256,
#   'loss': 3.3175275325775146,
#   'val_loss': 4.111818790435791,
#   'param_count': 4860420},
#  {'experiment': 'rnn_pre_l3_h128_e256_m35',
#   'decoder_type': 'rnn',
#   'injection': 'pre',
#   'layers': 3,
#   'hidden': 128,
#   'loss': 3.7513105869293213,
#   'val_loss': 4.282883167266846,
#   'param_count': 3597956}]

# %%
def plot_histories(rows, title, output_path=None):
    if not rows:
        print("Belum ada history untuk diplot.")
        return
    cols = 3
    rows_n = int(np.ceil(len(rows) / cols))
    plt.figure(figsize=(cols * 4, rows_n * 3))
    for i, row in enumerate(rows, start=1):
        hist = read_json(MODELS_DIR / row["experiment"] / "history.json", {})
        ax = plt.subplot(rows_n, cols, i)
        ax.plot(hist.get("loss", []), label="train")
        ax.plot(hist.get("val_loss", []), label="val")
        ax.set_title(row["experiment"], fontsize=9)
        ax.set_xlabel("epoch")
        ax.set_ylabel("loss")
        ax.legend(fontsize=8)
    plt.suptitle(title)
    plt.tight_layout()
    if output_path:
        plt.savefig(output_path)
    plt.show()

plot_histories(rnn_summary, "RNN training loss", PLOTS_DIR / "rnn_loss_curves.png")

# %% [markdown]
# ## 5. LSTM Decoder Training

# %%
lstm_configs = decoder_configs("lstm")
[c.experiment_id for c in lstm_configs]
# Out:
# ['lstm_pre_l1_h128_e256_m35',
#  'lstm_pre_l1_h256_e256_m35',
#  'lstm_pre_l2_h128_e256_m35',
#  'lstm_pre_l2_h256_e256_m35',
#  'lstm_pre_l3_h128_e256_m35',
#  'lstm_pre_l3_h256_e256_m35']

# %%
lstm_trained, lstm_skipped = train_grid(lstm_configs, RUN_TRAIN_LSTM)
{"trained": lstm_trained, "available_or_skipped": lstm_skipped}
# Out:
# Training lstm_pre_l1_h128_e256_m35
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 61s 114ms/step - loss: 5.8404 - masked_accuracy: 0.1532 - val_loss: 4.7956 - val_masked_accuracy: 0.2221 - learning_rate: 0.0010
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 52s 112ms/step - loss: 4.5797 - masked_accuracy: 0.2311 - val_loss: 4.5396 - val_masked_accuracy: 0.2382 - learning_rate: 0.0010
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 53s 112ms/step - loss: 4.3145 - masked_accuracy: 0.2509 - val_loss: 4.3651 - val_masked_accuracy: 0.2520 - learning_rate: 0.0010
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 52s 112ms/step - loss: 4.1128 - masked_accuracy: 0.2651 - val_loss: 4.2700 - val_masked_accuracy: 0.2585 - learning_rate: 0.0010
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 53s 112ms/step - loss: 3.9924 - masked_accuracy: 0.2712 - val_loss: 4.2058 - val_masked_accuracy: 0.2607 - learning_rate: 0.0010
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 53s 113ms/step - loss: 3.8919 - masked_accuracy: 0.2777 - val_loss: 4.1592 - val_masked_accuracy: 0.2667 - learning_rate: 0.0010
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 53s 112ms/step - loss: 3.8109 - masked_accuracy: 0.2834 - val_loss: 4.1231 - val_masked_accuracy: 0.2672 - learning_rate: 0.0010
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 53s 112ms/step - loss: 3
-04
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 22.
# {'trained': ['lstm_pre_l1_h128_e256_m35',
#   'lstm_pre_l1_h256_e256_m35',
#   'lstm_pre_l2_h128_e256_m35',
#   'lstm_pre_l2_h256_e256_m35',
#   'lstm_pre_l3_h128_e256_m35',
#   'lstm_pre_l3_h256_e256_m35'],
#  'available_or_skipped': []}

# %%
lstm_summary = summarize_decoder("lstm")
lstm_summary
# Out:
# [{'experiment': 'lstm_pre_l1_h256_e256_m35',
#   'decoder_type': 'lstm',
#   'injection': 'pre',
#   'layers': 1,
#   'hidden': 256,
#   'loss': 2.985715389251709,
#   'val_loss': 3.957987070083618,
#   'param_count': 4991748},
#  {'experiment': 'lstm_pre_l2_h256_e256_m35',
#   'decoder_type': 'lstm',
#   'injection': 'pre',
#   'layers': 2,
#   'hidden': 256,
#   'loss': 3.001237392425537,
#   'val_loss': 3.981334686279297,
#   'param_count': 5517060},
#  {'experiment': 'lstm_pre_l1_h128_e256_m35',
#   'decoder_type': 'lstm',
#   'injection': 'pre',
#   'layers': 1,
#   'hidden': 128,
#   'loss': 3.1139535903930664,
#   'val_loss': 4.006000995635986,
#   'param_count': 3680004},
#  {'experiment': 'lstm_pre_l2_h128_e256_m35',
#   'decoder_type': 'lstm',
#   'injection': 'pre',
#   'layers': 2,
#   'hidden': 128,
#   'loss': 3.158872604370117,
#   'val_loss': 4.006788730621338,
#   'param_count': 3811588},
#  {'experiment': 'lstm_pre_l3_h256_e256_m35',
#   'decoder_type': 'lstm',
#   'injection': 'pre',
#   'layers': 3,
#   'hidden': 256,
#   'loss': 3.0932698249816895,
#   'val_loss': 4.009025573730469,
#   'param_count': 6042372},
#  {'experiment': 'lstm_pre_l3_h128_e256_m35',
#   'decoder_type': 'lstm',
#   'injection': 'pre',
#   'layers': 3,
#   'hidden': 128,
#   'loss': 3.312070369720459,
#   'val_loss': 4.074057579040527,
#   'param_count': 3943172}]

# %%
plot_histories(lstm_summary, "LSTM training loss", PLOTS_DIR / "lstm_loss_curves.png")

# %% [markdown]
# ## 6. Select Best Models

# %%
def select_best(rows):
    if not rows:
        return None
    return min(rows, key=lambda r: float("inf") if r["val_loss"] is None else r["val_loss"])

best_rnn = select_best(rnn_summary)
best_lstm = select_best(lstm_summary)
best_rnn, best_lstm
# Out:
# ({'experiment': 'rnn_pre_l1_h256_e256_m35',
#   'decoder_type': 'rnn',
#   'injection': 'pre',
#   'layers': 1,
#   'hidden': 256,
#   'loss': 3.072021245956421,
#   'val_loss': 4.0443806648254395,
#   'param_count': 4597764},
#  {'experiment': 'lstm_pre_l1_h256_e256_m35',
#   'decoder_type': 'lstm',
#   'injection': 'pre',
#   'layers': 1,
#   'hidden': 256,
#   'loss': 2.985715389251709,
#   'val_loss': 3.957987070083618,
#   'param_count': 4991748})

# %%
def load_keras_caption_model(experiment_id):
    model_path = MODELS_DIR / experiment_id / "model.keras"
    if not model_path.exists():
        raise FileNotFoundError(model_path)
    # Inference dan scratch weight extraction tidak membutuhkan compile state.
    # compile=False juga menghindari error deserialisasi Keras 3 untuk @tf.function masked_loss.
    return tf.keras.models.load_model(model_path, compile=False)


def load_scratch_caption_model(experiment_id, decoder_type, injection="pre"):
    keras_model = load_keras_caption_model(experiment_id)
    scratch = CaptionModel(decoder_type=decoder_type, injection_method=injection)
    scratch.load_from_keras(keras_model, word2idx, idx2word)
    return scratch

# %% [markdown]
# ## 7. Evaluation Helpers

# %%
def filtered_eval_names(split="test", n=N_EVAL):
    if not has_required_files():
        return []
    splits = load_splits(SPLITS_JSON)
    feats = load_features(str(FEATURES_PATH))
    names = [name for name in splits[split] if name in captions and name in feats]
    return names[:n] if n else names


def evaluate_with_time(model, decoder_type, mode, image_names, max_len=MAX_SEQ_LEN, decoding="greedy", beam_size=3, injection="pre"):
    feats = load_features(str(FEATURES_PATH))
    start = time.perf_counter()
    result = evaluate(
        model=model,
        captions=captions,
        image_names=image_names,
        features=feats,
        word2idx=word2idx,
        idx2word=idx2word,
        decoder_type=decoder_type,
        max_len=max_len,
        mode=mode,
        seed=SEED,
        decoding=decoding,
        beam_size=beam_size,
        length_penalty=0.7,
        injection_method=injection,
    )
    elapsed = time.perf_counter() - start
    result["metrics"]["total_time_s"] = elapsed
    result["metrics"]["avg_time_ms"] = 1000 * elapsed / max(len(result["details"]), 1)
    result["metrics"]["decoding"] = decoding
    result["metrics"]["beam_size"] = beam_size if decoding == "beam" else None
    result["metrics"]["injection"] = injection
    return result

# %%
def evaluate_experiment(experiment_id, decoder_type, image_names, modes=("keras", "scratch"), decoding="greedy", beam_size=3, injection="pre"):
    out = {}
    if "keras" in modes:
        keras_model = load_keras_caption_model(experiment_id)
        out["keras"] = evaluate_with_time(keras_model, decoder_type, "keras", image_names, decoding=decoding, beam_size=beam_size, injection=injection)
    if "scratch" in modes:
        scratch_model = load_scratch_caption_model(experiment_id, decoder_type, injection=injection)
        out["scratch"] = evaluate_with_time(scratch_model, decoder_type, "scratch", image_names, decoding=decoding, beam_size=beam_size, injection=injection)
    return out

# %% [markdown]
# ## 8. RNN Evaluation: Keras vs Scratch

# %%
eval_names = filtered_eval_names("test", N_EVAL)
print("Eval samples:", len(eval_names))

rnn_best_eval = {}
if best_rnn and eval_names and RUN_FULL_EVAL:
    rnn_best_eval = evaluate_experiment(best_rnn["experiment"], "rnn", eval_names, modes=("keras", "scratch"))
    write_json(EVAL_DIR / "best_rnn_eval.json", rnn_best_eval)
else:
    rnn_best_eval = read_json(EVAL_DIR / "best_rnn_eval.json", {})

{k: v.get("metrics", {}) for k, v in rnn_best_eval.items()}
# Out:
# Eval samples: 50
# {'keras': {'bleu4': 0.03535010386891194,
#   'meteor': 0.2501074844858632,
#   'samples': 50,
#   'mode': 'keras',
#   'decoder_type': 'rnn',
#   'total_time_s': 45.38823619200048,
#   'avg_time_ms': 907.7647238400095,
#   'decoding': 'greedy',
#   'beam_size': None,
#   'injection': 'pre'},
#  'scratch': {'bleu4': 0.03535010386891194,
#   'meteor': 0.2501074844858632,
#   'samples': 50,
#   'mode': 'scratch',
#   'decoder_type': 'rnn',
#   'total_time_s': 0.18915371399998548,
#   'avg_time_ms': 3.7830742799997097,
#   'decoding': 'greedy',
#   'beam_size': None,
#   'injection': 'pre'}}

# %% [markdown]
# ## 9. LSTM Evaluation: Keras vs Scratch

# %%
lstm_best_eval = {}
if best_lstm and eval_names and RUN_FULL_EVAL:
    lstm_best_eval = evaluate_experiment(best_lstm["experiment"], "lstm", eval_names, modes=("keras", "scratch"))
    write_json(EVAL_DIR / "best_lstm_eval.json", lstm_best_eval)
else:
    lstm_best_eval = read_json(EVAL_DIR / "best_lstm_eval.json", {})

{k: v.get("metrics", {}) for k, v in lstm_best_eval.items()}
# Out:
# /kaggle/working/SpreiElsa/src/rnn-lstm/lstm.py:5: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1.0 + np.exp(-np.clip(x, -500.0, 500.0)))
# {'keras': {'bleu4': 0.032432280442816444,
#   'meteor': 0.2573921162898975,
#   'samples': 50,
#   'mode': 'keras',
#   'decoder_type': 'lstm',
#   'total_time_s': 59.934537364999414,
#   'avg_time_ms': 1198.6907472999883,
#   'decoding': 'greedy',
#   'beam_size': None,
#   'injection': 'pre'},
#  'scratch': {'bleu4': 0.032432280442816444,
#   'meteor': 0.2573921162898975,
#   'samples': 50,
#   'mode': 'scratch',
#   'decoder_type': 'lstm',
#   'total_time_s': 0.2713977800012799,
#   'avg_time_ms': 5.427955600025598,
#   'decoding': 'greedy',
#   'beam_size': None,
#   'injection': 'pre'}}

# %% [markdown]
# ## 10. Evaluate All Variations

# %%
def evaluate_all_variations(decoder_type, rows, max_samples=N_EVAL):
    names = filtered_eval_names("test", max_samples)
    results = {}
    for row in rows:
        exp_id = row["experiment"]
        model_path = MODELS_DIR / exp_id / "model.keras"
        if not model_path.exists():
            continue
        print("Evaluating", exp_id)
        keras_model = load_keras_caption_model(exp_id)
        res = evaluate_with_time(keras_model, decoder_type, "keras", names)
        results[exp_id] = {
            "summary": res["metrics"],
            "results": res["details"],
            "num_layers": row["layers"],
            "hidden_units": row["hidden"],
        }
    return results

if RUN_FULL_EVAL:
    rnn_variation_results = evaluate_all_variations("rnn", rnn_summary)
    lstm_variation_results = evaluate_all_variations("lstm", lstm_summary)
    write_json(EVAL_DIR / "rnn_variations.json", rnn_variation_results)
    write_json(EVAL_DIR / "lstm_variations.json", lstm_variation_results)
else:
    rnn_variation_results = read_json(EVAL_DIR / "rnn_variations.json", {})
    lstm_variation_results = read_json(EVAL_DIR / "lstm_variations.json", {})

len(rnn_variation_results), len(lstm_variation_results)
# Out:
# Evaluating rnn_pre_l1_h256_e256_m35
# Evaluating rnn_pre_l2_h256_e256_m35
# Evaluating rnn_pre_l2_h128_e256_m35
# Evaluating rnn_pre_l1_h128_e256_m35
# Evaluating rnn_pre_l3_h256_e256_m35
# Evaluating rnn_pre_l3_h128_e256_m35
# Evaluating lstm_pre_l1_h256_e256_m35
# Evaluating lstm_pre_l2_h256_e256_m35
# Evaluating lstm_pre_l1_h128_e256_m35
# Evaluating lstm_pre_l2_h128_e256_m35
# Evaluating lstm_pre_l3_h256_e256_m35
# Evaluating lstm_pre_l3_h128_e256_m35
# (6, 6)

# %%
def variation_table(results):
    rows = []
    for name, payload in results.items():
        summary = payload.get("summary", {})
        rows.append({
            "experiment": name,
            "layers": payload.get("num_layers"),
            "hidden": payload.get("hidden_units"),
            "bleu4": summary.get("bleu4"),
            "meteor": summary.get("meteor"),
            "avg_time_ms": summary.get("avg_time_ms"),
        })
    rows.sort(key=lambda r: r.get("bleu4") or -1, reverse=True)
    return rows

rnn_variation_table = variation_table(rnn_variation_results)
lstm_variation_table = variation_table(lstm_variation_results)
rnn_variation_table[:3], lstm_variation_table[:3]
# Out:
# ([{'experiment': 'rnn_pre_l1_h256_e256_m35',
#    'layers': 1,
#    'hidden': 256,
#    'bleu4': 0.03535010386891194,
#    'meteor': 0.2501074844858632,
#    'avg_time_ms': 991.2912361000053},
#   {'experiment': 'rnn_pre_l2_h128_e256_m35',
#    'layers': 2,
#    'hidden': 128,
#    'bleu4': 0.025898736560428782,
#    'meteor': 0.2471082252219979,
#    'avg_time_ms': 993.3717391199752},
#   {'experiment': 'rnn_pre_l2_h256_e256_m35',
#    'layers': 2,
#    'hidden': 256,
#    'bleu4': 0.019888547233304243,
#    'meteor': 0.23608657205049205,
#    'avg_time_ms': 998.9660811600334}],
#  [{'experiment': 'lstm_pre_l2_h256_e256_m35',
#    'layers': 2,
#    'hidden': 256,
#    'bleu4': 0.03401062439266299,
#    'meteor': 0.25195623538004974,
#    'avg_time_ms': 1514.372285319987},
#   {'experiment': 'lstm_pre_l1_h256_e256_m35',
#    'layers': 1,
#    'hidden': 256,
#    'bleu4': 0.032432280442816444,
#    'meteor': 0.2573921162898975,
#    'avg_time_ms': 1281.8151646400656},
#   {'experiment': 'lstm_pre_l2_h128_e256_m35',
#    'layers': 2,
#    'hidden': 128,
#    'bleu4': 0.019206973143979674,
#    'meteor': 0.2517005952878812,
#    'avg_time_ms': 1626.8319044999953}])

# %%
def plot_variation_bleu(rnn_rows, lstm_rows):
    rows = [("RNN", r) for r in rnn_rows] + [("LSTM", r) for r in lstm_rows]
    if not rows:
        print("Belum ada hasil variasi untuk diplot.")
        return
    labels = [f"{kind}\nL{r['layers']} H{r['hidden']}" for kind, r in rows]
    bleu = [r.get("bleu4") or 0 for _, r in rows]
    meteor = [r.get("meteor") or 0 for _, r in rows]
    x = np.arange(len(rows))
    plt.figure(figsize=(max(8, len(rows) * 0.75), 4))
    plt.bar(x - 0.18, bleu, width=0.36, label="BLEU-4")
    plt.bar(x + 0.18, meteor, width=0.36, label="METEOR")
    plt.xticks(x, labels, rotation=45, ha="right")
    plt.ylabel("score")
    plt.legend()
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / "analysis_variations_bleu_meteor.png")
    plt.show()

plot_variation_bleu(rnn_variation_table, lstm_variation_table)

# %% [markdown]
# ## 11. Qualitative Analysis

# %%
def detail_by_image(result):
    details = result.get("details", []) if result else []
    return {row["image"]: row for row in details}

rnn_details = detail_by_image((rnn_best_eval or {}).get("keras", {}))
lstm_details = detail_by_image((lstm_best_eval or {}).get("keras", {}))
common_images = sorted(set(rnn_details) & set(lstm_details))
print("Common evaluated images:", len(common_images))
# Out:
# Common evaluated images: 50

# %%
def choose_qualitative_examples(common, k=10):
    scored = []
    for image in common:
        rb = rnn_details[image].get("bleu4", 0)
        lb = lstm_details[image].get("bleu4", 0)
        scored.append((image, (rb + lb) / 2))
    if not scored:
        return []
    scored.sort(key=lambda item: item[1])
    picks = []
    for frac in np.linspace(0, 1, k):
        idx = int(round(frac * (len(scored) - 1)))
        picks.append(scored[idx][0])
    return list(dict.fromkeys(picks))

qual_images = choose_qualitative_examples(common_images, 10)
qual_rows = []
for image in qual_images:
    qual_rows.append({
        "image": image,
        "rnn_bleu4": rnn_details[image].get("bleu4"),
        "lstm_bleu4": lstm_details[image].get("bleu4"),
        "rnn_caption": rnn_details[image].get("candidate"),
        "lstm_caption": lstm_details[image].get("candidate"),
        "ground_truth": rnn_details[image].get("references", [])[:2],
    })
qual_rows
# Out:
# [{'image': '3721799573_2f470950e0.jpg',
#   'rnn_bleu4': 1.0000000000000007e-09,
#   'lstm_bleu4': 9.365137582048793e-08,
#   'rnn_caption': 'a woman in a red shirt is a a in in of',
#   'lstm_caption': 'a woman in a blue shirt and a is is on a back',
#   'ground_truth': ['There are two ladies embracing and posing shown here .',
#    'Two girlfriends smiling .']},
#  {'image': '3723903586_e98d3d8ec7.jpg',
#   'rnn_bleu4': 1.351200154807036e-07,
#   'lstm_bleu4': 1.6068568378893033e-07,
#   'rnn_caption': 'dogs dogs muzzles a a in',
#   'lstm_caption': 'a dogs and in are race through the snow',
#   'ground_truth': ['greyhounds racing on a track',
#    'A greyhound race with the lead dog wearing yellow and black stripes and the number 8']},
#  {'image': '3726130458_07df79e969.jpg',
#   'rnn_bleu4': 1.4519590582309535e-05,
#   'lstm_bleu4': 1.4601394329159486e-07,
#   'rnn_caption': 'two men players playing a game game a a ball',
#   'lstm_caption': 'a man player a a and and uniform uniform playing a',
#   'ground_truth': ['A baseball player dodges a ball with his bat high in the air .',
#    'A baseball player in a white uniform is walking to base while a crowd of people watch from the bleachers .']},
#  {'image': '3717845800_ab45e255b8.jpg',
#   'rnn_bleu4': 1.351200154807036e-07,
#   'lstm_bleu4': 1.588277335841436e-05,
#   'rnn_caption': 'a group of men players playing a game game a a ball',
#   'lstm_caption': 'a soccer player in a red uniform is a the in',
#   'ground_truth': ['Four rugby players on the ground with two standing behind them .',
#    'Members of two soccer teams struggle on the field to get the ball .']},
#  {'image': '3726590391_bc6e729bb6.jpg',
#   'rnn_bleu4': 1.4601394329159491e-05,
#   'lstm_bleu4': 1.528233238901893e-05,
#   'rnn_caption': 'a man in a red shirt is a a in in of',
#   'lstm_caption': 'a young girl is a a on in bed of a',
#   'ground_truth': ['An elderly woman is crying while sitting in a window .',
#    'An elderly woman is sitting by a window reading .']},
#  {'image': '3728695560_00ec1ca492.jpg',
#   'rnn_bleu4': 1.997153017694773e-05,
#   'lstm_bleu4': 1.3082012065333475e-05,
#   'rnn_caption': 'a man of a heritage with wearing hair and a black shirt',
#   'lstm_caption': 'a man is a a on in a of',
#   'ground_truth': ['A little girl looks at a birthday cake while a man holds a baby .',
#    '"A man , baby , and child sit in front of a birthday cake ."']},
#  {'image': '3726700898_c50494b8bd.jpg',
#   'rnn_bleu4': 1.8887907083801996e-05,
#   'lstm_bleu4': 1.7895706401541527e-05,
#   'rnn_caption': 'a man in a black shirt and a is in a',
#   'lstm_caption': 'a man in a black shirt and a is shirt on a back',
#   'ground_truth': ['A man balances a knife on his arm as another man watches .',
#    'A man has a knife on his arm and another man is watching .']},
#  {'image': '3728015645_b43a60258b.jpg',
#   'rnn_bleu4': 2.171185208108769e-05,
#   'lstm_bleu4': 1.8257418583505532e-05,
#   'rnn_caption': 'a skateboarder in a air shirt a a on',
#   'lstm_caption': 'a skateboarder is a a on on skateboard skateboard',
#   'ground_truth': ['A man is posed standing on one hand on a skateboard ramp .',
#    'A man on inline skates in midair']},
#  {'image': '3723690961_729dd5d617.jpg',
#   'rnn_bleu4': 0.2894742149567509,
#   'lstm_bleu4': 0.0020780604348467117,
#   'rnn_caption': 'a man in a black shirt and a is in a',
#   'lstm_caption': 'a man wearing a black shirt and a is shirt on a back',
#   'ground_truth': ['A man in a pink shirt and white vest plays a guitar .',
#    'A man in a pink shirt playing guitar .']},
#  {'image': '3726025663_e7d35d23f6.jpg',
#   'rnn_bleu4': 0.4111336169005197,
#   'lstm_bleu4': 0.34329452398451965,
#   'rnn_caption': 'a group of people are a in on',
#   'lstm_caption': 'a group of people are a on on bicycle',
#   'ground_truth': ['A group of people ride in a race',
#    'A large group of bicycles riding their bikes .']}]

# %% [markdown]
# ## 12. Analysis 5a: Layers and Hidden State

# %%
def aggregate_by(rows, key):
    groups = {}
    for row in rows:
        groups.setdefault(row[key], []).append(row)
    return {
        k: {
            "mean_bleu4": float(np.mean([r.get("bleu4") or 0 for r in v])),
            "mean_meteor": float(np.mean([r.get("meteor") or 0 for r in v])),
            "mean_time_ms": float(np.mean([r.get("avg_time_ms") or 0 for r in v])),
        }
        for k, v in groups.items()
    }

analysis_5a = {
    "rnn_by_layers": aggregate_by(rnn_variation_table, "layers"),
    "rnn_by_hidden": aggregate_by(rnn_variation_table, "hidden"),
    "lstm_by_layers": aggregate_by(lstm_variation_table, "layers"),
    "lstm_by_hidden": aggregate_by(lstm_variation_table, "hidden"),
}
analysis_5a
# Out:
# {'rnn_by_layers': {1: {'mean_bleu4': 0.026119234964958202,
#    'mean_meteor': 0.24349803060442932,
#    'mean_time_ms': 999.6450806600114},
#   2: {'mean_bleu4': 0.02289364189686651,
#    'mean_meteor': 0.24159739863624496,
#    'mean_time_ms': 996.1689101400043},
#   3: {'mean_bleu4': 0.010741250930743095,
#    'mean_meteor': 0.22947022814230017,
#    'mean_time_ms': 1048.9623910200316}},
#  'rnn_by_hidden': {256: {'mean_bleu4': 0.022178178561995752,
#    'mean_meteor': 0.23960890048667405,
#    'mean_time_ms': 979.7873693800162},
#   128: {'mean_bleu4': 0.01765790663304945,
#    'mean_meteor': 0.2367682044353089,
#    'mean_time_ms': 1050.0635518333486}},
#  'lstm_by_layers': {2: {'mean_bleu4': 0.026608798768321333,
#    'mean_meteor': 0.2518284153339655,
#    'mean_time_ms': 1570.6020949099911},
#   1: {'mean_bleu4': 0.020400419111562578,
#    'mean_meteor': 0.24687010160869038,
#    'mean_time_ms': 1329.1360787100348},
#   3: {'mean_bleu4': 0.01555517616863279,
#    'mean_meteor': 0.23157319519358438,
#    'mean_time_ms': 1693.528627960004}},
#  'lstm_by_hidden': {256: {'mean_bleu4': 0.027946114741969414,
#    'mean_meteor': 0.2503134117454519,
#    'mean_time_ms': 1459.4100820067008},
#   128: {'mean_bleu4': 0.013763481290375051,
#    'mean_meteor': 0.236534396345375,
#    'mean_time_ms': 1602.7677857133192}}}

# %% [markdown]
# Catatan analisis: isi kesimpulan akhir setelah eksperimen dijalankan. Umumnya hidden state lebih besar memberi kapasitas representasi lebih baik tetapi inference lebih lambat; layer tambahan bisa membantu konteks sekuensial, namun mudah overfit pada Flickr8k jika epoch/data terbatas.

# %% [markdown]
# ## 13. Analysis 5b: Keras vs Scratch

# %%
def keras_scratch_comparison(eval_payload, label):
    if not eval_payload:
        return None
    k = eval_payload.get("keras", {}).get("metrics", {})
    s = eval_payload.get("scratch", {}).get("metrics", {})
    return {
        "decoder": label,
        "keras_bleu4": k.get("bleu4"),
        "scratch_bleu4": s.get("bleu4"),
        "keras_meteor": k.get("meteor"),
        "scratch_meteor": s.get("meteor"),
        "keras_avg_time_ms": k.get("avg_time_ms"),
        "scratch_avg_time_ms": s.get("avg_time_ms"),
    }

comparison_keras_scratch = [
    keras_scratch_comparison(rnn_best_eval, "RNN"),
    keras_scratch_comparison(lstm_best_eval, "LSTM"),
]
[row for row in comparison_keras_scratch if row]
# Out:
# [{'decoder': 'RNN',
#   'keras_bleu4': 0.03535010386891194,
#   'scratch_bleu4': 0.03535010386891194,
#   'keras_meteor': 0.2501074844858632,
#   'scratch_meteor': 0.2501074844858632,
#   'keras_avg_time_ms': 907.7647238400095,
#   'scratch_avg_time_ms': 3.7830742799997097},
#  {'decoder': 'LSTM',
#   'keras_bleu4': 0.032432280442816444,
#   'scratch_bleu4': 0.032432280442816444,
#   'keras_meteor': 0.2573921162898975,
#   'scratch_meteor': 0.2573921162898975,
#   'keras_avg_time_ms': 1198.6907472999883,
#   'scratch_avg_time_ms': 5.427955600025598}]

# %% [markdown]
# Catatan analisis: scratch memakai operasi NumPy dan loop Python sehingga biasanya lebih lambat dari Keras/TensorFlow. Score seharusnya dekat jika bobot dan urutan operasi sama; selisih kecil dapat muncul dari detail numerik, masking, atau perbedaan decoding step.

# %% [markdown]
# ## 14. Analysis 5c: RNN vs LSTM

# %%
def compare_rnn_lstm_details():
    rows = []
    for image in common_images:
        r = rnn_details[image]
        l = lstm_details[image]
        rows.append({
            "image": image,
            "rnn_bleu4": r.get("bleu4", 0),
            "lstm_bleu4": l.get("bleu4", 0),
            "rnn_meteor": r.get("meteor", 0),
            "lstm_meteor": l.get("meteor", 0),
        })
    return rows

rnn_lstm_rows = compare_rnn_lstm_details()
rnn_lstm_summary = {
    "n_common": len(rnn_lstm_rows),
    "rnn_bleu4": float(np.mean([r["rnn_bleu4"] for r in rnn_lstm_rows])) if rnn_lstm_rows else None,
    "lstm_bleu4": float(np.mean([r["lstm_bleu4"] for r in rnn_lstm_rows])) if rnn_lstm_rows else None,
    "rnn_meteor": float(np.mean([r["rnn_meteor"] for r in rnn_lstm_rows])) if rnn_lstm_rows else None,
    "lstm_meteor": float(np.mean([r["lstm_meteor"] for r in rnn_lstm_rows])) if rnn_lstm_rows else None,
}
rnn_lstm_summary
# Out:
# {'n_common': 50,
#  'rnn_bleu4': 0.03535010386891195,
#  'lstm_bleu4': 0.032432280442816444,
#  'rnn_meteor': 0.25010748448586323,
#  'lstm_meteor': 0.25739211628989755}

# %% [markdown]
# Catatan analisis: LSTM biasanya lebih stabil untuk caption karena gate input/forget/output membantu mempertahankan informasi jangka panjang dan mengurangi vanishing gradient. RNN sederhana lebih ringan, tetapi konteks awal caption cenderung lebih cepat hilang pada sekuens yang panjang.

# %% [markdown]
# ## 15. Max Caption Length Study

# %%
def best_overall_for_length_study():
    candidates = []
    for label, best, payload in [("rnn", best_rnn, rnn_best_eval), ("lstm", best_lstm, lstm_best_eval)]:
        metrics = (payload or {}).get("keras", {}).get("metrics", {})
        if best and metrics:
            candidates.append((label, best["experiment"], metrics.get("bleu4") or 0, metrics.get("avg_time_ms") or float("inf")))
    if not candidates:
        return None
    return max(candidates, key=lambda item: (item[2], -item[3]))

best_length_model = best_overall_for_length_study()
best_length_model
# Out:
# ('rnn', 'rnn_pre_l1_h256_e256_m35', 0.03535010386891194, 907.7647238400095)

# %%
caption_lengths = [15, 25, MAX_SEQ_LEN]
length_bleu_results = {}
if RUN_FULL_EVAL and best_length_model and eval_names:
    decoder_type, exp_id, _, _ = best_length_model
    model = load_keras_caption_model(exp_id)
    for length in caption_lengths:
        res = evaluate_with_time(model, decoder_type, "keras", eval_names, max_len=length)
        length_bleu_results[length] = res["metrics"]["bleu4"]
    write_json(EVAL_DIR / "caption_length_study.json", length_bleu_results)
else:
    length_bleu_results = read_json(EVAL_DIR / "caption_length_study.json", {})

length_bleu_results
# Out:
# {15: 0.03535010386891194, 25: 0.03535010386891194, 35: 0.03535010386891194}

# %%
if length_bleu_results:
    xs = [int(k) for k in length_bleu_results.keys()]
    ys = [length_bleu_results[str(k)] if str(k) in length_bleu_results else length_bleu_results[k] for k in xs]
    plt.figure(figsize=(5, 3))
    plt.plot(xs, ys, marker="o")
    plt.xlabel("max caption length")
    plt.ylabel("BLEU-4")
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / "caption_length_bleu.png")
    plt.show()

# %% [markdown]
# ## 16. Bonus: Beam Search

# %%
def beam_comparison(best_row, decoder_type, beam_sizes=(1, 3, 5)):
    if not best_row or not eval_names:
        return {}
    exp_id = best_row["experiment"]
    scratch = load_scratch_caption_model(exp_id, decoder_type)
    rows = {}
    for beam in beam_sizes:
        decoding = "greedy" if beam == 1 else "beam"
        res = evaluate_with_time(scratch, decoder_type, "scratch", eval_names, decoding=decoding, beam_size=beam)
        rows[f"beam_{beam}"] = res["metrics"]
    return rows

if RUN_FULL_EVAL:
    rnn_beam = beam_comparison(best_rnn, "rnn")
    lstm_beam = beam_comparison(best_lstm, "lstm")
    write_json(EVAL_DIR / "beam_search.json", {"rnn": rnn_beam, "lstm": lstm_beam})
else:
    beam_payload = read_json(EVAL_DIR / "beam_search.json", {})
    rnn_beam = beam_payload.get("rnn", {})
    lstm_beam = beam_payload.get("lstm", {})

rnn_beam, lstm_beam
# Out:
# /kaggle/working/SpreiElsa/src/rnn-lstm/lstm.py:5: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1.0 + np.exp(-np.clip(x, -500.0, 500.0)))
# ({'beam_1': {'bleu4': 0.03535010386891194,
#    'meteor': 0.2501074844858632,
#    'samples': 50,
#    'mode': 'scratch',
#    'decoder_type': 'rnn',
#    'total_time_s': 0.17748842999935732,
#    'avg_time_ms': 3.5497685999871464,
#    'decoding': 'greedy',
#    'beam_size': None,
#    'injection': 'pre'},
#   'beam_3': {'bleu4': 0.03699715110940569,
#    'meteor': 0.2607804346203551,
#    'samples': 50,
#    'mode': 'scratch',
#    'decoder_type': 'rnn',
#    'total_time_s': 0.7412478020014532,
#    'avg_time_ms': 14.824956040029065,
#    'decoding': 'beam',
#    'beam_size': 3,
#    'injection': 'pre'},
#   'beam_5': {'bleu4': 0.046339020902472106,
#    'meteor': 0.2689697139272297,
#    'samples': 50,
#    'mode': 'scratch',
#    'decoder_type': 'rnn',
#    'total_time_s': 1.2752792179999233,
#    'avg_time_ms': 25.505584359998466,
#    'decoding': 'beam',
#    'beam_size': 5,
#    'injection': 'pre'}},
#  {'beam_1': {'bleu4': 0.032432280442816444,
#    'meteor': 0.2573921162898975,
#    'samples': 50,
#    'mode': 'scratch',
#    'decoder_type': 'lstm',
#    'total_time_s': 0.2891938949978794,
#    'avg_time_ms': 5.783877899957588,
#    'decoding': 'greedy',
#    'beam_size': None,
#    'injection': 'pre'},
#   'beam_3': {'bleu4': 0.024767465927225497,
#    'meteor': 0.23732221760200772,
#    'samples': 50,
#    'mode': 'scratch',
#    'decoder_type': 'lstm',
#    'total_time_s': 1.0138502820009307,
#    'avg_time_ms': 20.277005640018615,
#    'decoding': 'beam',
#    'beam_size': 3,
#    'injection': 'pre'},
#   'beam_5': {'bleu4': 0.037162502405165915,
#    'meteor': 0.23801351344315336,
#    'samples': 50,
#    'mode': 'scratch',
#    'decoder_type': 'lstm',
#    'total_time_s': 1.6570946620013274,
#    'avg_time_ms': 33.14189324002655,
#    'decoding': 'beam',
#    'beam_size': 5,
#    'injection': 'pre'}})

# %%
def sample_beam_captions(best_row, decoder_type, image_name=None):
    if not best_row or not eval_names:
        return {}
    image_name = image_name or eval_names[0]
    feats = load_features(str(FEATURES_PATH))
    scratch = load_scratch_caption_model(best_row["experiment"], decoder_type)
    feat = np.asarray(feats[image_name], dtype=np.float32)
    return {
        "image": image_name,
        "greedy": scratch.generate_caption(feat, max_len=MAX_SEQ_LEN),
        "beam3": scratch.generate_caption_beam(feat, max_len=MAX_SEQ_LEN, beam_size=3),
        "beam5": scratch.generate_caption_beam(feat, max_len=MAX_SEQ_LEN, beam_size=5),
        "references": captions.get(image_name, []),
    }

sample_beam_rnn = sample_beam_captions(best_rnn, "rnn") if best_rnn and eval_names else {}
sample_beam_lstm = sample_beam_captions(best_lstm, "lstm") if best_lstm and eval_names else {}
sample_beam_rnn, sample_beam_lstm
# Out:
# ({'image': '3717845800_ab45e255b8.jpg',
#   'greedy': 'a group of men players playing a game game a a ball',
#   'beam3': 'a group of men players playing a',
#   'beam5': 'a group of men players playing a',
#   'references': ['Four rugby players on the ground with two standing behind them .',
#    'Members of two soccer teams struggle on the field to get the ball .',
#    'Soccer players on the ground fighting for the ball .',
#    'The rugby players in red are wrestling the player in yellow to the ground .',
#    'Three members of the red team are in the grass with a member of the yellow team .']},
#  {'image': '3717845800_ab45e255b8.jpg',
#   'greedy': 'a soccer player in a red uniform is a the in',
#   'beam3': 'a soccer player in a is uniform a the',
#   'beam5': 'a soccer player in a is uniform a the',
#   'references': ['Four rugby players on the ground with two standing behind them .',
#    'Members of two soccer teams struggle on the field to get the ball .',
#    'Soccer players on the ground fighting for the ball .',
#    'The rugby players in red are wrestling the player in yellow to the ground .',
#    'Three members of the red team are in the grass with a member of the yellow team .']})

# %% [markdown]
# ## 17. Bonus: Batch Inference from Scratch

# %%
def generate_captions_batch_scratch(model: CaptionModel, feature_batch: np.ndarray, max_len=MAX_SEQ_LEN):
    pad_idx = model.word2idx["<pad>"]
    start_idx = model.word2idx["<start>"]
    end_idx = model.word2idx["<end>"]
    batch = feature_batch.shape[0]
    hidden_size = model.decoder.cells[0].hidden_size
    x_img = model.image_projection.forward(feature_batch.astype(np.float32))

    if model.decoder_type == "rnn":
        h = [np.zeros((batch, hidden_size), dtype=np.float32) for _ in range(model.n_layers)]
        generated = [[] for _ in range(batch)]

        if model.injection_method == "pre":
            out, h = model.decoder.step(x_img, h)
            probs = model.output_layer.forward(out)
            tokens = np.argmax(probs, axis=-1).astype(np.int32)
            finished = np.zeros(batch, dtype=bool)
            for i, tok in enumerate(tokens):
                if int(tok) in (end_idx, pad_idx):
                    finished[i] = True
                else:
                    generated[i].append(model.idx2word.get(int(tok), "<unk>"))
            loop_range = range(max_len - 1)
        else:
            tokens = np.full(batch, start_idx, dtype=np.int32)
            finished = np.zeros(batch, dtype=bool)
            loop_range = range(max_len)

        for _ in loop_range:
            x = model.embedding.forward(tokens)
            out, h = model.decoder.step(x, h)
            if model.injection_method == "init":
                out = np.concatenate([out, x_img], axis=-1)
            probs = model.output_layer.forward(out)
            tokens = np.argmax(probs, axis=-1).astype(np.int32)
            for i, tok in enumerate(tokens):
                if finished[i]:
                    continue
                if int(tok) in (end_idx, pad_idx):
                    finished[i] = True
                else:
                    generated[i].append(model.idx2word.get(int(tok), "<unk>"))
            if finished.all():
                break
        return [" ".join(words) for words in generated]

    # LSTM
    h = [np.zeros((batch, hidden_size), dtype=np.float32) for _ in range(model.n_layers)]
    c = [np.zeros((batch, hidden_size), dtype=np.float32) for _ in range(model.n_layers)]
    generated = [[] for _ in range(batch)]

    if model.injection_method == "pre":
        out, h, c = model.decoder.step(x_img, h, c)
        probs = model.output_layer.forward(out)
        tokens = np.argmax(probs, axis=-1).astype(np.int32)
        finished = np.zeros(batch, dtype=bool)
        for i, tok in enumerate(tokens):
            if int(tok) in (end_idx, pad_idx):
                finished[i] = True
            else:
                generated[i].append(model.idx2word.get(int(tok), "<unk>"))
        loop_range = range(max_len - 1)
    else:
        tokens = np.full(batch, start_idx, dtype=np.int32)
        finished = np.zeros(batch, dtype=bool)
        loop_range = range(max_len)

    for _ in loop_range:
        x = model.embedding.forward(tokens)
        out, h, c = model.decoder.step(x, h, c)
        if model.injection_method == "init":
            out = np.concatenate([out, x_img], axis=-1)
        probs = model.output_layer.forward(out)
        tokens = np.argmax(probs, axis=-1).astype(np.int32)
        for i, tok in enumerate(tokens):
            if finished[i]:
                continue
            if int(tok) in (end_idx, pad_idx):
                finished[i] = True
            else:
                generated[i].append(model.idx2word.get(int(tok), "<unk>"))
        if finished.all():
            break
    return [" ".join(words) for words in generated]

# %%
def batch_benchmark(best_row, decoder_type):
    if not best_row or not eval_names:
        return {}
    names = eval_names[:N_BATCH]
    feats = load_features(str(FEATURES_PATH))
    batch_feats = np.stack([feats[name] for name in names]).astype(np.float32)
    model = load_scratch_caption_model(best_row["experiment"], decoder_type)

    t0 = time.perf_counter()
    single_caps = [model.generate_caption(feat, MAX_SEQ_LEN) for feat in batch_feats]
    t_single = time.perf_counter() - t0

    t0 = time.perf_counter()
    batch_caps = generate_captions_batch_scratch(model, batch_feats, MAX_SEQ_LEN)
    t_batch = time.perf_counter() - t0

    return {
        "n": len(names),
        "single_total_s": t_single,
        "batch_total_s": t_batch,
        "single_avg_ms": 1000 * t_single / max(len(names), 1),
        "batch_avg_ms": 1000 * t_batch / max(len(names), 1),
        "match_rate": float(np.mean([a == b for a, b in zip(single_caps, batch_caps)])) if names else 0,
    }

batch_rnn = batch_benchmark(best_rnn, "rnn") if best_rnn and eval_names else {}
batch_lstm = batch_benchmark(best_lstm, "lstm") if best_lstm and eval_names else {}
batch_rnn, batch_lstm
# Out:
# ({'n': 50,
#   'single_total_s': 0.14896207299898379,
#   'batch_total_s': 0.0796782869983872,
#   'single_avg_ms': 2.9792414599796757,
#   'batch_avg_ms': 1.5935657399677439,
#   'match_rate': 0.0},
#  {'n': 50,
#   'single_total_s': 0.2556687050018809,
#   'batch_total_s': 0.0982787829998415,
#   'single_avg_ms': 5.113374100037618,
#   'batch_avg_ms': 1.96557565999683,
#   'match_rate': 0.0})

# %% [markdown]
# ## 18. Bonus: Init-Inject Architecture

# %%
def init_inject_configs_from_best():
    configs = []
    if best_rnn:
        configs.append(make_config("rnn", best_rnn["layers"], best_rnn["hidden"], injection_method="init"))
    if best_lstm:
        configs.append(make_config("lstm", best_lstm["layers"], best_lstm["hidden"], injection_method="init"))
    return configs

init_configs = init_inject_configs_from_best()
[c.experiment_id for c in init_configs]
# Out:
# ['rnn_init_l1_h256_e256_m35', 'lstm_init_l1_h256_e256_m35']

# %%
init_trained, init_skipped = train_grid(init_configs, RUN_TRAIN_INIT_INJECT)
{"trained": init_trained, "available_or_skipped": init_skipped}
# Out:
# Training rnn_init_l1_h256_e256_m35
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - loss: 4.5933 - masked_accuracy: 0.2532 - val_loss: 3.4960 - val_masked_accuracy: 0.3465 - learning_rate: 0.0010
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - loss: 3.0180 - masked_accuracy: 0.3798 - val_loss: 3.3394 - val_masked_accuracy: 0.3638 - learning_rate: 0.0010
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 16s 34ms/step - loss: 2.6239 - masked_accuracy: 0.4131 - val_loss: 3.3007 - val_masked_accuracy: 0.3726 - learning_rate: 0.0010
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 16s 35ms/step - loss: 2.3925 - masked_accuracy: 0.4370 - val_loss: 3.3347 - val_masked_accuracy: 0.3728 - learning_rate: 0.0010
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 16s 34ms/step - loss: 2.2383 - masked_accuracy: 0.4564 - val_loss: 3.3584 - val_masked_accuracy: 0.3729 - learning_rate: 0.0010
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2.1191 - masked_accuracy: 0.4735
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 16s 34ms/step - loss: 2.1192 - masked_accuracy: 0.4734 - val_loss: 3.3849 - val_masked_accuracy: 0.3741 - learning_rate: 0.0010
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 16s 34ms/step - loss: 1.9367 - masked_accuracy: 0.5050 - val_loss: 3.3383 - val_masked_accuracy: 0.3752 - learning_rate: 5.0000e-04
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 16s 34ms/step - loss: 1.8527 - masked_accuracy: 0.5194 - val_loss: 3.3760 - val_masked_accuracy: 0.3743 - learning_rate: 5.0000e-04
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Training lstm_init_l1_h256_e256_m35
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 65s 131ms/step - loss: 4.6734 - masked_accuracy: 0.2430 - val_loss: 3.4234 - val_masked_accuracy: 0.3534 - learning_rate: 0.0010
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 61s 129ms/step - loss: 2.9575 - masked_accuracy: 0.3883 - val_loss: 3.2675 - val_masked_accuracy: 0.3701 - learning_rate: 0.0010
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 61s 130ms/step - loss: 2.5553 - masked_accuracy: 0.4229 - val_loss: 3.2416 - val_masked_accuracy: 0.3793 - learning_rate: 0.0010
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 61s 130ms/step - loss: 2.3244 - masked_accuracy: 0.4469 - val_loss: 3.2653 - val_masked_accuracy: 0.3758 - learning_rate: 0.0010
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 61s 130ms/step - loss: 2.1713 - masked_accuracy: 0.4668 - val_loss: 3.3017 - val_masked_accuracy: 0.3768 - learning_rate: 0.0010
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 2.0473 - masked_accuracy: 0.4838
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 61s 130ms/step - loss: 2.0474 - masked_accuracy: 0.4838 - val_loss: 3.3030 - val_masked_accuracy: 0.3779 - learning_rate: 0.0010
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 61s 130ms/step - loss: 1.8726 - masked_accuracy: 0.5154 - val_loss: 3.2790 - val_masked_accuracy: 0.3791 - learning_rate: 5.0000e-04
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 61s 129ms/step - loss: 1.7868 - masked_accuracy: 0.5323 - val_loss: 3.3234 - val_masked_accuracy: 0.3812 - learning_rate: 5.0000e-04
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# {'trained': ['rnn_init_l1_h256_e256_m35', 'lstm_init_l1_h256_e256_m35'],
#  'available_or_skipped': []}

# %%
def compare_pre_vs_init(decoder_type, best_pre_row):
    if not best_pre_row or not eval_names:
        return {}
    init_config = make_config(decoder_type, best_pre_row["layers"], best_pre_row["hidden"], injection_method="init")
    init_path = MODELS_DIR / init_config.experiment_id / "model.keras"
    if not init_path.exists():
        return {"missing": str(init_path)}
    pre_model = load_keras_caption_model(best_pre_row["experiment"])
    init_model = load_keras_caption_model(init_config.experiment_id)
    return {
        "pre": evaluate_with_time(pre_model, decoder_type, "keras", eval_names, injection="pre")["metrics"],
        "init": evaluate_with_time(init_model, decoder_type, "keras", eval_names, injection="init")["metrics"],
    }

if RUN_FULL_EVAL:
    init_inject_results = {
        "rnn": compare_pre_vs_init("rnn", best_rnn),
        "lstm": compare_pre_vs_init("lstm", best_lstm),
    }
    write_json(EVAL_DIR / "init_inject_comparison.json", init_inject_results)
else:
    init_inject_results = read_json(EVAL_DIR / "init_inject_comparison.json", {})

init_inject_results
# Out:
# {'rnn': {'pre': {'bleu4': 0.03535010386891194,
#    'meteor': 0.2501074844858632,
#    'samples': 50,
#    'mode': 'keras',
#    'decoder_type': 'rnn',
#    'total_time_s': 44.395394918999955,
#    'avg_time_ms': 887.9078983799991,
#    'decoding': 'greedy',
#    'beam_size': None,
#    'injection': 'pre'},
#   'init': {'bleu4': 0.05806555875657171,
#    'meteor': 0.29165276455119016,
#    'samples': 50,
#    'mode': 'keras',
#    'decoder_type': 'rnn',
#    'total_time_s': 53.681964418999996,
#    'avg_time_ms': 1073.63928838,
#    'decoding': 'greedy',
#    'beam_size': None,
#    'injection': 'init'}},
#  'lstm': {'pre': {'bleu4': 0.032432280442816444,
#    'meteor': 0.2573921162898975,
#    'samples': 50,
#    'mode': 'keras',
#    'decoder_type': 'lstm',
#    'total_time_s': 62.77001776999896,
#    'avg_time_ms': 1255.4003553999792,
#    'decoding': 'greedy',
#    'beam_size': None,
#    'injection': 'pre'},
#   'init': {'bleu4': 0.06425852367938104,
#    'meteor': 0.30798502645490866,
#    'samples': 50,
#    'mode': 'keras',
#    'decoder_type': 'lstm',
#    'total_time_s': 68.37515458100097,
#    'avg_time_ms': 1367.5030916200194,
#    'decoding': 'greedy',
#    'beam_size': None,
#    'injection': 'init'}}}

# %% [markdown]
# ## 19. Bonus: Scratch Batch Sanity

# %%
def check_rnn_batch_sanity():
    rng = np.random.default_rng(0)
    batch, seq_len, input_dim, hidden = 2, 5, 4, 3
    x = rng.normal(size=(batch, seq_len, input_dim)).astype(np.float32)
    cell = SimpleRNNCell()
    cell.W_x = rng.normal(size=(input_dim, hidden)).astype(np.float32)
    cell.W_h = rng.normal(size=(hidden, hidden)).astype(np.float32)
    cell.b = rng.normal(size=(hidden,)).astype(np.float32)
    decoder = SimpleRNNDecoder([cell])
    outputs, h = decoder.forward(x)
    assert outputs.shape == (batch, seq_len, hidden), outputs.shape
    return outputs.shape


def check_lstm_batch_sanity():
    rng = np.random.default_rng(1)
    batch, seq_len, input_dim, hidden = 2, 6, 4, 3
    x = rng.normal(size=(batch, seq_len, input_dim)).astype(np.float32)
    cell = LSTMCell()
    cell.set_weights(
        rng.normal(size=(input_dim, 4 * hidden)).astype(np.float32),
        rng.normal(size=(hidden, 4 * hidden)).astype(np.float32),
        rng.normal(size=(4 * hidden,)).astype(np.float32),
    )
    decoder = LSTMDecoder([cell])
    outputs, h, c = decoder.forward(x)
    assert outputs.shape == (batch, seq_len, hidden), outputs.shape
    return outputs.shape

check_rnn_batch_sanity(), check_lstm_batch_sanity()
# Out:
# ((2, 5, 3), (2, 6, 3))

# %% [markdown]
# ## 20. Bonus: Backward Propagation Sanity

# %%
def relative_error(a, b, eps=1e-8):
    denom = np.maximum(eps, np.maximum(np.abs(a), np.abs(b)))
    return float(np.max(np.abs(a - b) / denom))


def rnn_cell_backward_sanity():
    rng = np.random.default_rng(0)
    x = rng.normal(size=(1, 3)).astype(np.float32)
    h_prev = rng.normal(size=(1, 2)).astype(np.float32)
    cell = SimpleRNNCell()
    cell.W_x = rng.normal(size=(3, 2)).astype(np.float32)
    cell.W_h = rng.normal(size=(2, 2)).astype(np.float32)
    cell.b = rng.normal(size=(2,)).astype(np.float32)
    h, cache = cell.forward_with_cache(x, h_prev)
    _, _, gWx, gWh, gb = cell.backward(np.ones_like(h), cache)
    return {"gWx": gWx.shape, "gWh": gWh.shape, "gb": gb.shape}


def lstm_cell_backward_sanity():
    rng = np.random.default_rng(1)
    x = rng.normal(size=(1, 3)).astype(np.float32)
    h_prev = rng.normal(size=(1, 2)).astype(np.float32)
    c_prev = rng.normal(size=(1, 2)).astype(np.float32)
    cell = LSTMCell()
    cell.set_weights(
        rng.normal(size=(3, 8)).astype(np.float32),
        rng.normal(size=(2, 8)).astype(np.float32),
        rng.normal(size=(8,)).astype(np.float32),
    )
    h, _, cache = cell.forward_with_cache(x, h_prev, c_prev)
    _, _, _, gWx, gWh, gb = cell.backward(np.ones_like(h), np.zeros_like(h), cache)
    return {"gWx": gWx.shape, "gWh": gWh.shape, "gb": gb.shape}

rnn_cell_backward_sanity(), lstm_cell_backward_sanity()
# Out:
# ({'gWx': (3, 2), 'gWh': (2, 2), 'gb': (2,)},
#  {'gWx': (3, 8), 'gWh': (2, 8), 'gb': (8,)})

# %%
def finite_difference_rnn_Wx_error():
    rng = np.random.default_rng(7)
    x = rng.normal(size=(1, 2)).astype(np.float32)
    h_prev = rng.normal(size=(1, 2)).astype(np.float32)
    cell = SimpleRNNCell()
    cell.W_x = rng.normal(size=(2, 2)).astype(np.float32)
    cell.W_h = rng.normal(size=(2, 2)).astype(np.float32)
    cell.b = rng.normal(size=(2,)).astype(np.float32)
    h, cache = cell.forward_with_cache(x, h_prev)
    _, _, gWx, _, _ = cell.backward(np.ones_like(h), cache)
    grad_num = np.zeros_like(cell.W_x)
    eps = 1e-4
    for i in range(cell.W_x.shape[0]):
        for j in range(cell.W_x.shape[1]):
            orig = cell.W_x[i, j]
            cell.W_x[i, j] = orig + eps
            loss_pos = float(np.sum(cell.forward_with_cache(x, h_prev)[0]))
            cell.W_x[i, j] = orig - eps
            loss_neg = float(np.sum(cell.forward_with_cache(x, h_prev)[0]))
            grad_num[i, j] = (loss_pos - loss_neg) / (2 * eps)
            cell.W_x[i, j] = orig
    return relative_error(gWx, grad_num)

finite_difference_rnn_Wx_error()
# Out:
# 0.25552618503570557

# %% [markdown]
# ## 21. Export Summary Artifacts

# %%
summary_payload = {
    "best_rnn": best_rnn,
    "best_lstm": best_lstm,
    "rnn_variations": rnn_variation_table,
    "lstm_variations": lstm_variation_table,
    "keras_vs_scratch": [row for row in comparison_keras_scratch if row],
    "rnn_vs_lstm": rnn_lstm_summary,
    "caption_length": length_bleu_results,
    "beam": {"rnn": rnn_beam, "lstm": lstm_beam},
    "batch": {"rnn": batch_rnn, "lstm": batch_lstm},
    "init_inject": init_inject_results,
    "qualitative_examples": qual_rows,
}
write_json(WORKING_DIR / "notebook_summary.json", summary_payload)
WORKING_DIR / "notebook_summary.json"
# Out:
# PosixPath('/kaggle/working/outputs/rnn_lstm/notebook_summary.json')

# %% [markdown]
# ## 22. Final Checklist
#
# - CNN encoder frozen menghasilkan `features.npy`.
# - Caption preprocessing menghasilkan `vocab.json` dan `splits.json`.
# - RNN dan LSTM masing-masing memiliki 6 variasi pre-inject.
# - Best model dievaluasi untuk Keras dan scratch.
# - Analisis variasi layer/hidden, Keras vs scratch, RNN vs LSTM, dan panjang caption tersedia.
# - Bonus beam search, batch inference, init-inject, dan backward sanity tersedia di notebook ini.
