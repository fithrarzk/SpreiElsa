# %% [markdown]
# # Backward Sanity Checks
# Notebook ringkas untuk cek grad numerik CNN dan RNN/LSTM scratch.

# %%
import sys
from pathlib import Path

root = Path('.').resolve()
if str(root) not in sys.path:
    sys.path.insert(0, str(root))

rnn_path = Path('src/rnn-lstm').resolve()
if str(rnn_path) not in sys.path:
    sys.path.insert(0, str(rnn_path))

# %% [markdown]
# ## CNN backward

# %%
from importlib import import_module

cnn_tests = import_module('src.cnn.tests_backward')
cnn_tests.main()

# %% [markdown]
# ## RNN/LSTM backward

# %%
import tests_backward as rnn_tests

rnn_tests.main()
